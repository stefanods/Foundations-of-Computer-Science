# %% [markdown]
# # Starting from the Google Play Store dataset

# %%
# Caricamento librerie d'interesse
import pandas as pd
import numpy as np
import re

# %%
# Lettura dataset googleplaystore
playstore = pd.read_csv('googleplaystore.csv')
playstore.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
# Lettura Last Updated
date_re = re.compile('(?P<month>\w+)\s(?P<day>\d+)\,\s(?P<year>\d+)')
month_diz = {'January': 1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,
         'November':11,'December':12}

def parse_date(data):
    dm = date_re.match(data)
    if dm:
        day = int(dm.group('day'))
        if (day < 10):
            day = '0' + str(day)   
        month = month_diz[dm.group('month')]   
        year = dm.group('year')
        return (str(day)+str(month)+str(year))
    else:
        return(np.nan)
    
playstore['Last Updated'] = pd.to_datetime(playstore['Last Updated'].apply(parse_date), format='%d%m%Y')
playstore['Last Updated'].head()
# Out:
# 0   2018-01-07
# 1   2018-01-15
# 2   2018-08-01
# 3   2018-06-08
# 4   2018-06-20
# Name: Last Updated, dtype: datetime64[ns]

# %%
# Lettura dataset googleplaystore_user_reviews.csv
playstore_review = pd.read_csv('googleplaystore_user_reviews.csv')
playstore_review.head(2)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462

# %% [markdown]
# # Convert the app sizes to a number

# %%
#Ispezioni possibili moltiplicatori
print(playstore['Size'].isnull().any()) # No missing

def moltiplicatori_size(size):
    if re.search('[a-zA-Z]', size): 
        size = re.sub('[^a-zA-Z]', '', size) # Elimino tutto tranne lettere
    return(size)

list_molt = list(playstore['Size'].apply(moltiplicatori_size))

print(set(list_molt)) # Moltiplicatori sono k e M, presenza 1,000+

playstore[playstore['Size'] == '1,000+'] # Valori traslati di una variabile --> INDEX = 10472
# Out:
# False
# {'M', 'Varieswithdevice', '1,000+', 'k'}
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
re_size = re.compile('^(?P<num>\d+\.?\d*)(?P<moltiplicatore>\w{0,1})$')

def size_tonumber(app_size):
    r = re_size.match(app_size)
    diz = {'M' : 1000000, 'k' : 1000}
    if r:
        molt = diz[r.group('moltiplicatore')]
        app_size = float(r.group('num'))*molt
    return(app_size)

playstore['Size'] = playstore['Size'].apply(size_tonumber)
playstore['Size'].head()
# Out:
# 0    1.9e+07
# 1    1.4e+07
# 2    8.7e+06
# 3    2.5e+07
# 4    2.8e+06
# Name: Size, dtype: object

# %% [markdown]
# # Convert the number of installs to a number

# %%
# Ispezione possibili valori attributo Installs
print(playstore['Installs'].isnull().any()) # No missing
print(playstore.groupby('Installs').size())

# Presenza modalità 'Free'
playstore[playstore['Installs'] == 'Free'] # Valori traslati di una variabile, stesso record sopra
# Out:
# False
# Installs
# 0                    1
# 0+                  14
# 1+                  67
# 1,000+             907
# 1,000,000+        1579
# 1,000,000,000+      58
# 10+                386
# 10,000+           1054
# 10,000,000+       1252
# 100+               719
# 100,000+          1169
# 100,000,000+       409
# 5+                  82
# 5,000+             477
# 5,000,000+         752
# 50+                205
# 50,000+            479
# 50,000,000+        289
# 500+               330
# 500,000+           539
# 500,000,000+        72
# Free                 1
# dtype: int64
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
def installs_tonumber(serie):
    if (re.search('\d',serie)):
        serie = int(re.sub('\D', '', serie)) # Elimino tutti i caratteri esclusi i numerici
    return(serie)
        
playstore['Installs'] = playstore['Installs'].apply(installs_tonumber)
playstore['Installs'].head()
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: object

# %% [markdown]
# # Transform “Varies with device” into a missing value

# %%
def missing(valore):
    if (valore == 'Varies with device'):
        valore = np.nan
    return(valore)

variabili = list(playstore.columns)
for variabile in variabili:
    playstore[variabile] = playstore[variabile].apply(missing)

# %% [markdown]
# # Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
# Ispezione Android Ver
print(playstore['Android Ver'].isnull().any()) # Si missing

playstore.groupby('Android Ver').size() 
# La presenza del trattino indica due versioni, l'assenza indica una sola versione a cui segue una stringa
# Out:
# True
# Android Ver
# 1.0 and up          2
# 1.5 and up         20
# 1.6 and up        116
# 2.0 and up         32
# 2.0.1 and up        7
# 2.1 and up        134
# 2.2 - 7.1.1         1
# 2.2 and up        244
# 2.3 and up        652
# 2.3.3 and up      281
# 3.0 and up        241
# 3.1 and up         10
# 3.2 and up         36
# 4.0 and up       1375
# 4.0.3 - 7.1.1       2
# 4.0.3 and up     1501
# 4.1 - 7.1.1         1
# 4.1 and up       2451
# 4.2 and up        394
# 4.3 and up        243
# 4.4 and up        980
# 4.4W and up        12
# 5.0 - 6.0           1
# 5.0 - 7.1.1         1
# 5.0 - 8.0           2
# 5.0 and up        601
# 5.1 and up         24
# 6.0 and up         60
# 7.0 - 7.1.1         1
# 7.0 and up         42
# 7.1 and up          3
# 8.0 and up          6
# dtype: int64

# %%
vers_re = re.compile('^(?P<vers>\d\.\d\.{0,1}\d{0,1})')

def version(ver):
    if ver is not np.nan:
        temp = ver.split('-')
        if len(temp)>1: # In caso di trattino e quindi due versioni
            ver = str(temp[1].strip()) # Rimuovo spazi iniziali e finali del secondo elemento della lista
        else: 
            ver = vers_re.match(ver).group('vers')
    return(ver)

playstore['Android Ver'] = playstore['Android Ver'].apply(version)
playstore['Android Ver'].head()
# Out:
# 0    4.0.3
# 1    4.0.3
# 2    4.0.3
# 3      4.2
# 4      4.4
# Name: Android Ver, dtype: object

# %%
print(playstore['Current Ver'].isnull().any()) # Si missing
playstore.groupby('Current Ver').size()
# Out:
# True
# Current Ver
# 0.0.0.2                      1
# 0.0.1                       15
# 0.0.10                       1
# 0.0.2                        4
# 0.0.3                        2
# 0.0.4                        3
# 0.0.42                       1
# 0.0.44                       1
# 0.0.5                        3
# 0.0.52                       1
# 0.0.53                       1
# 0.0.6                        1
# 0.0.7                        3
# 0.0.73                       1
# 0.0.80                       1
# 0.0.9                        5
# 0.1                         13
# 0.1.0                        2
# 0.1.1                        3
# 0.1.10.0                     1
# 0.1.100944346                2
# 0.1.11                       1
# 0.1.187945513                1
# 0.1.2                        1
# 0.1.219                      1
# 0.1.22                       1
# 0.1.27                       1
# 0.1.5                        1
# 0.1.6                        1
# 0.1.7                        1
#                             ..
# v150                         1
# v2                           1
# v2.0.02_prod                 1
# v2.6.0                       1
# v2.7.10.6                    1
# v2.7.11.16                   1
# v2.7.11.27                   1
# v2.7.11.6                    2
# v2017.Dec.01.19              1
# v2018.Apr.12.16              1
# v2018.May.15.14              1
# v3                           1
# v3.1.1                       1
# v3.4.0-3                     1
# v3.7.93                      2
# v3.9f                        1
# v4.29.0.9                    1
# v4.30.0.8                    2
# v4.30.0.9                    1
# v5.4.3                       1
# v6.1                         1
# v6.6.0                       1
# v6.7.14                      1
# v67_slk3.0_20180115_01       1
# v7.0.02.3.0516.1_06_0713     1
# v7.0.7.1.0625.1_06_0629      1
# v7.0.9.1.0526.1_06_0704      1
# v8.0.1.8.0629.1              1
# v8[1.0.10]                   1
# version 0.994                1
# Length: 2831, dtype: int64

# %%
def current_ver_clean(ver):
    if ver is not np.nan:
        ver = re.sub('[^\d\.]', '', ver) # Elimino tutte le lettere e i caratteri che non sono punti
        if (len(ver)>1 and ver[0] == '.'): # Rimuovere il punto iniziale se presente
             ver = ver[1:]
        if ((ver == '') or (ver == '.')): # Tali casi si presentano quando il valore originale è una parola
            return(np.nan)              
    return(ver)

playstore['Current Ver'] = playstore['Current Ver'].apply(current_ver_clean)
playstore['Current Ver'].head()
# Out:
# 0    1.0.0
# 1    2.0.0
# 2    1.2.4
# 3      NaN
# 4      1.1
# Name: Current Ver, dtype: object

# %% [markdown]
# # Remove the duplicates

# %%
#Da questo punto in poi conviene eliminare il record numero 10472 in quanto traslato
playstore = playstore.drop(10472)
#Per ogni app, viene/vengono selezionato/i i record che presentano meno recensioni in quanto meno recenti
playstore['Reviews'] = playstore['Reviews'].astype(int)
duplicati = playstore.sort_values(by=['App','Reviews'],ascending=True)
duplicati_cut = duplicati[duplicati.duplicated(subset=['App'], keep='last')]

# %%
playstore = playstore.drop(duplicati_cut.index)

# %% [markdown]
# # For each category, compute the number of apps

# %%
playstore.groupby('Category').size()
# Out:
# Category
# ART_AND_DESIGN           61
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     222
# BUSINESS                420
# COMICS                   56
# COMMUNICATION           315
# DATING                  170
# EDUCATION               105
# ENTERTAINMENT            86
# EVENTS                   64
# FAMILY                 1878
# FINANCE                 345
# FOOD_AND_DRINK          112
# GAME                    945
# HEALTH_AND_FITNESS      288
# HOUSE_AND_HOME           73
# LIBRARIES_AND_DEMO       84
# LIFESTYLE               369
# MAPS_AND_NAVIGATION     131
# MEDICAL                 395
# NEWS_AND_MAGAZINES      254
# PARENTING                60
# PERSONALIZATION         376
# PHOTOGRAPHY             281
# PRODUCTIVITY            374
# SHOPPING                202
# SOCIAL                  239
# SPORTS                  325
# TOOLS                   829
# TRAVEL_AND_LOCAL        219
# VIDEO_PLAYERS           164
# WEATHER                  79
# dtype: int64

# %% [markdown]
# # For each category, compute the average rating

# %%
playstore.groupby('Category')['Rating'].mean()
# Out:
# Category
# ART_AND_DESIGN         4.359322
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.344970
# BUSINESS               4.098479
# COMICS                 4.181481
# COMMUNICATION          4.121484
# DATING                 3.980451
# EDUCATION              4.349038
# ENTERTAINMENT          4.129070
# EVENTS                 4.435556
# FAMILY                 4.184150
# FINANCE                4.115563
# FOOD_AND_DRINK         4.171277
# GAME                   4.244432
# HEALTH_AND_FITNESS     4.243033
# HOUSE_AND_HOME         4.140984
# LIBRARIES_AND_DEMO     4.178125
# LIFESTYLE              4.093355
# MAPS_AND_NAVIGATION    4.036441
# MEDICAL                4.165862
# NEWS_AND_MAGAZINES     4.121569
# PARENTING              4.300000
# PERSONALIZATION        4.332215
# PHOTOGRAPHY            4.155894
# PRODUCTIVITY           4.183389
# SHOPPING               4.230556
# SOCIAL                 4.247291
# SPORTS                 4.216154
# TOOLS                  4.040278
# TRAVEL_AND_LOCAL       4.069519
# VIDEO_PLAYERS          4.044966
# WEATHER                4.243056
# Name: Rating, dtype: float64

# %% [markdown]
# # Create two dataframes: one for the genres and one bridging apps and genders. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
print(playstore['Genres'].isnull().any()) # No missing

lista_app = []
lista_genres = []

for index,row in playstore.iterrows():
    l_generi = row['Genres'].split(';')
    for genre in l_generi:
        lista_genres.append(genre)
        lista_app.append(row['App'])

app_genre = pd.DataFrame({'App' : lista_app, 'Genres_one' : lista_genres})
# Out:
# False

# %%
# Vi sono duplicati in quanto alcune app hanno due volte lo stesso genere all'interno della variabile 'Genre'
print(app_genre[app_genre.duplicated(keep=False)].head())
# Ad esempio:
print(playstore[playstore['App'] == 'Learn Japanese, Korean, Chinese Offline & Free'][['App','Genres']])

# Rimozione di tali duplicati:
app_genre = app_genre.drop_duplicates()
app_genre.head()
# Out:
#                                                 App Genres_one
# 531  Learn Japanese, Korean, Chinese Offline & Free  Education
# 532  Learn Japanese, Korean, Chinese Offline & Free  Education
# 534                        Dinosaurs Coloring Pages  Education
# 535                        Dinosaurs Coloring Pages  Education
# 548                              ABC Preschool Free  Education
#                                                 App               Genres
# 712  Learn Japanese, Korean, Chinese Offline & Free  Education;Education
#                                                  App    Genres_one
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 2                              Sketch - Draw & Paint  Art & Design
# 3              Pixel Draw - Number Art Coloring Book  Art & Design
# 4              Pixel Draw - Number Art Coloring Book    Creativity

# %%
# genre_1 = []
# genre_2 = []

# for index,row in playstore.iterrows():
#     l_generi = row['Genres'].split(';')
#     genre_1.append(l_generi[0])
#     if len(l_generi)<2:
#         genre_2.append(np.nan)
#     else:
#         genre_2.append(l_generi[1])
        
# df_2 = pd.DataFrame({'App' : playstore['App'], 'Genre_1' : genre_1, 'Genre_2' : genre_2})
# df_2.head()

# %%
df_genres = pd.DataFrame({'Genres' : list(set(lista_genres))})
df_genres.head()
# Out:
#               Genres
# 0       Productivity
# 1              Board
# 2           Strategy
# 3  Books & Reference
# 4          Education

# %% [markdown]
# # For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
l_false = [False] * playstore.shape[0] # Lista di False
lista_generi = list(set(lista_genres)) # Lista con generi univoci

for genere in lista_generi:
    playstore[genere] = l_false # Inserisco in Playstore un attributo per ogni genere i cui valori sono tutti False
    
for index,row in playstore.iterrows():
    appoggio = row['Genres'].split(';')
    for genre in appoggio:
        playstore.at[index, genre.strip()] = True # Setto a True tutti i valori degli attributi riguardanti il genere/generi dell'app

playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme       ART_AND_DESIGN
# 31                                     Art Drawing Ideas       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type Price Content Rating  \
# 0         4.1      159  1.9e+07     10000  Free     0       Everyone
# 2         4.7    87510  8.7e+06   5000000  Free     0       Everyone
# 3         4.5   215644  2.5e+07  50000000  Free     0           Teen
# 4         4.3      967  2.8e+06    100000  Free     0       Everyone
# 5         4.4      167  5.6e+06     50000  Free     0       Everyone
# 6         3.8      178  1.9e+07     50000  Free     0       Everyone
# 7         4.1    36815  2.9e+07   1000000  Free     0       Everyone
# 8         4.4    13791  3.3e+07   1000000  Free     0       Everyone
# 9         4.7      121  3.1e+06     10000  Free     0       Everyone
# 10        4.4    13880  2.8e+07   1000000  Free     0       Everyone
# 11        4.4     8788  1.2e+07   1000000  Free     0       Everyone
# 12        4.2    44829    2e+07  10000000  Free     0           Teen
# 13        4.6     4326  2.1e+07    100000  Free     0       Everyone
# 14        4.4     1518  3.7e+07    100000  Free     0       Everyone
# 15        3.2       55  2.7e+06      5000  Free     0       Everyone
# 16        4.7     3632  5.5e+06    500000  Free     0       Everyone
# 17        4.5       27  1.7e+07     10000  Free     0       Everyone
# 18        4.3   194216  3.9e+07   5000000  Free     0       Everyone
# 19        4.6   224399  3.1e+07  10000000  Free     0       Everyone
# 20        4.0      450  1.4e+07    100000  Free     0       Everyone
# 21        4.1      654  1.2e+07    100000  Free     0       Everyone
# 22        4.7     7699  4.2e+06    500000  Free     0   Everyone 10+
# 24        4.7      118  2.3e+07     50000  Free     0       Everyone
# 25        4.8      192    6e+06     10000  Free     0       Everyone
# 26        4.7    20260  2.5e+07    500000  Free     0       Everyone
# 27        4.1      203  6.1e+06    100000  Free     0       Everyone
# 28        3.9      136  4.6e+06     10000  Free     0       Everyone
# 29        4.1      223  4.2e+06    100000  Free     0       Everyone
# 30        4.2     1120  9.2e+06    100000  Free     0       Everyone
# 31        4.1      227  5.2e+06     50000  Free     0       Everyone
# ...       ...      ...      ...       ...   ...   ...            ...
# 10811     NaN        4  3.9e+06       100  Free     0       Everyone
# 10812     4.1       80  1.3e+07      1000  Free     0       Everyone
# 10813     NaN       20  2.7e+06     10000  Free     0       Everyone
# 10814     4.0      785  3.1e+07     50000  Free     0           Teen
# 10815     4.2     5775  4.9e+06    500000  Free     0       Everyone
# 10816     NaN        2  6.8e+06       100  Free     0       Everyone
# 10817     4.0      885    8e+06    100000  Free     0       Everyone
# 10818     NaN       96  1.5e+06     10000  Free     0       Everyone
# 10819     3.3       52  3.6e+06      5000  Free     0           Teen
# 10820     5.0       22  8.6e+06      1000  Free     0           Teen
# 10821     NaN        6  2.5e+06        50  Free     0       Everyone
# 10822     NaN        0  3.1e+06        10  Free     0       Everyone
# 10823     NaN        1  2.9e+06       100  Free     0       Everyone
# 10824     NaN       67  8.2e+07     10000  Free     0       Everyone
# 10825     NaN        7  7.7e+06       100  Free     0           Teen
# 10826     4.0    88486      NaN   5000000  Free     0     Mature 17+
# 10827     4.2      117  1.3e+07      5000  Free     0       Everyone
# 10828     3.4      291  1.3e+07     10000  Free     0       Everyone
# 10829     4.6      603  7.4e+06     10000  Free     0       Everyone
# 10830     3.8      881  2.3e+06    100000  Free     0       Everyone
# 10831     NaN       38  9.8e+06      5000  Free     0       Everyone
# 10832     3.8     1195   582000    100000  Free     0       Everyone
# 10833     4.8       44   619000      1000  Free     0       Everyone
# 10834     4.0        7  2.6e+06       500  Free     0       Everyone
# 10835     NaN        0  9.6e+06        10  Free     0       Everyone
# 10836     4.5       38  5.3e+07      5000  Free     0       Everyone
# 10837     5.0        4  3.6e+06       100  Free     0       Everyone
# 10838     NaN        3  9.5e+06      1000  Free     0       Everyone
# 10839     4.5      114      NaN      1000  Free     0     Mature 17+
# 10840     4.5   398307  1.9e+07  10000000  Free     0       Everyone
#
#                         Genres  ...   Action Business Art & Design  Casual  \
# 0                 Art & Design  ...    False    False         True   False
# 2                 Art & Design  ...    False    False         True   False
# 3                 Art & Design  ...    False    False         True   False
# 4      Art & Design;Creativity  ...    False    False         True   False
# 5                 Art & Design  ...    False    False         True   False
# 6                 Art & Design  ...    False    False         True   False
# 7                 Art & Design  ...    False    False         True   False
# 8                 Art & Design  ...    False    False         True   False
# 9      Art & Design;Creativity  ...    False    False         True   False
# 10                Art & Design  ...    False    False         True   False
# 11                Art & Design  ...    False    False         True   False
# 12                Art & Design  ...    False    False         True   False
# 13                Art & Design  ...    False    False         True   False
# 14                Art & Design  ...    False    False         True   False
# 15                Art & Design  ...    False    False         True   False
# 16                Art & Design  ...    False    False         True   False
# 17                Art & Design  ...    False    False         True   False
# 18                Art & Design  ...    False    False         True   False
# 19                Art & Design  ...    False    False         True   False
# 20                Art & Design  ...    False    False         True   False
# 21                Art & Design  ...    False    False         True   False
# 22                Art & Design  ...    False    False         True   False
# 24                Art & Design  ...    False    False         True   False
# 25                Art & Design  ...    False    False         True   False
# 26     Art & Design;Creativity  ...    False    False         True   False
# 27                Art & Design  ...    False    False         True   False
# 28                Art & Design  ...    False    False         True   False
# 29                Art & Design  ...    False    False         True   False
# 30                Art & Design  ...    False    False         True   False
# 31                Art & Design  ...    False    False         True   False
# ...                        ...  ...      ...      ...          ...     ...
# 10811          Auto & Vehicles  ...    False    False        False   False
# 10812                Education  ...    False    False        False   False
# 10813                 Business  ...    False     True        False   False
# 10814            Entertainment  ...    False    False        False   False
# 10815        Books & Reference  ...    False    False        False   False
# 10816                 Business  ...    False     True        False   False
# 10817                    Tools  ...    False    False        False   False
# 10818                  Finance  ...    False    False        False   False
# 10819        Books & Reference  ...    False    False        False   False
# 10820                Education  ...    False    False        False   False
# 10821            Entertainment  ...    False    False        False   False
# 10822             Productivity  ...    False    False        False   False
# 10823  Video Players & Editors  ...    False    False        False   False
# 10824                  Medical  ...    False    False        False   False
# 10825                   Social  ...    False    False        False   False
# 10826                   Social  ...    False    False        False   False
# 10827                Education  ...    False    False        False   False
# 10828                   Comics  ...    False    False        False   False
# 10829        Books & Reference  ...    False    False        False   False
# 10830         News & Magazines  ...    False    False        False   False
# 10831        Maps & Navigation  ...    False    False        False   False
# 10832                  Weather  ...    False    False        False   False
# 10833        Books & Reference  ...    False    False        False   False
# 10834                Education  ...    False    False        False   False
# 10835                 Business  ...    False     True        False   False
# 10836                Education  ...    False    False        False   False
# 10837                Education  ...    False    False        False   False
# 10838                  Medical  ...    False    False        False   False
# 10839        Books & Reference  ...    False    False        False   False
# 10840                Lifestyle  ...    False    False        False   False
#
#        Comics  Beauty  Auto & Vehicles  Action & Adventure  Social  Tools
# 0       False   False            False               False   False  False
# 2       False   False            False               False   False  False
# 3       False   False            False               False   False  False
# 4       False   False            False               False   False  False
# 5       False   False            False               False   False  False
# 6       False   False            False               False   False  False
# 7       False   False            False               False   False  False
# 8       False   False            False               False   False  False
# 9       False   False            False               False   False  False
# 10      False   False            False               False   False  False
# 11      False   False            False               False   False  False
# 12      False   False            False               False   False  False
# 13      False   False            False               False   False  False
# 14      False   False            False               False   False  False
# 15      False   False            False               False   False  False
# 16      False   False            False               False   False  False
# 17      False   False            False               False   False  False
# 18      False   False            False               False   False  False
# 19      False   False            False               False   False  False
# 20      False   False            False               False   False  False
# 21      False   False            False               False   False  False
# 22      False   False            False               False   False  False
# 24      False   False            False               False   False  False
# 25      False   False            False               False   False  False
# 26      False   False            False               False   False  False
# 27      False   False            False               False   False  False
# 28      False   False            False               False   False  False
# 29      False   False            False               False   False  False
# 30      False   False            False               False   False  False
# 31      False   False            False               False   False  False
# ...       ...     ...              ...                 ...     ...    ...
# 10811   False   False             True               False   False  False
# 10812   False   False            False               False   False  False
# 10813   False   False            False               False   False  False
# 10814   False   False            False               False   False  False
# 10815   False   False            False               False   False  False
# 10816   False   False            False               False   False  False
# 10817   False   False            False               False   False   True
# 10818   False   False            False               False   False  False
# 10819   False   False            False               False   False  False
# 10820   False   False            False               False   False  False
# 10821   False   False            False               False   False  False
# 10822   False   False            False               False   False  False
# 10823   False   False            False               False   False  False
# 10824   False   False            False               False   False  False
# 10825   False   False            False               False    True  False
# 10826   False   False            False               False    True  False
# 10827   False   False            False               False   False  False
# 10828    True   False            False               False   False  False
# 10829   False   False            False               False   False  False
# 10830   False   False            False               False   False  False
# 10831   False   False            False               False   False  False
# 10832   False   False            False               False   False  False
# 10833   False   False            False               False   False  False
# 10834   False   False            False               False   False  False
# 10835   False   False            False               False   False  False
# 10836   False   False            False               False   False  False
# 10837   False   False            False               False   False  False
# 10838   False   False            False               False   False  False
# 10839   False   False            False               False   False  False
# 10840   False   False            False               False   False  False
#
# [9659 rows x 66 columns]

# %% [markdown]
# # For each genre, compute the average rating. What is the genre with highest average?

# %%
dff = pd.merge(app_genre, playstore, on='App')
dff.groupby('Genres_one')['Rating'].mean()
# Out:
# Genres_one
# Action                     4.247697
# Action & Adventure         4.288542
# Adventure                  4.191026
# Arcade                     4.277838
# Art & Design               4.350000
# Auto & Vehicles            4.190411
# Beauty                     4.278571
# Board                      4.291228
# Books & Reference          4.343275
# Brain Games                4.358065
# Business                   4.098479
# Card                       4.082609
# Casino                     4.286486
# Casual                     4.141014
# Comics                     4.181481
# Communication              4.121790
# Creativity                 4.306250
# Dating                     3.980451
# Education                  4.290018
# Educational                4.100000
# Entertainment              4.093028
# Events                     4.435556
# Finance                    4.115563
# Food & Drink               4.171277
# Health & Fitness           4.243496
# House & Home               4.140984
# Libraries & Demo           4.178125
# Lifestyle                  4.094040
# Maps & Navigation          4.036441
# Medical                    4.165862
# Music                      4.219048
# Music & Audio              4.300000
# Music & Video              4.229032
# News & Magazines           4.121569
# Parenting                  4.300000
# Personalization            4.332215
# Photography                4.155894
# Pretend Play               4.238235
# Productivity               4.183389
# Puzzle                     4.370732
# Racing                     4.174757
# Role Playing               4.272072
# Shopping                   4.230556
# Simulation                 4.154500
# Social                     4.247291
# Sports                     4.225185
# Strategy                   4.227368
# Tools                      4.040278
# Travel & Local             4.069519
# Trivia                     4.039286
# Video Players & Editors    4.044667
# Weather                    4.243056
# Word                       4.318182
# Name: Rating, dtype: float64

# %%
# Rating medio massimo
dff.groupby('Genres_one')['Rating'].mean().idxmax()
# Out:
# 'Events'

# %% [markdown]
# # For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
# Ispezione price
print(playstore.Price.isnull().any()) # No missing
playstore.groupby('Price').size() # Quindi il valore o è 0 o ha come valuta il $
# Out:
# False
# Price
# $0.99       145
# $1.00         3
# $1.04         1
# $1.20         1
# $1.26         1
# $1.29         1
# $1.49        46
# $1.50         1
# $1.59         1
# $1.61         1
# $1.70         2
# $1.75         1
# $1.76         1
# $1.96         1
# $1.97         1
# $1.99        73
# $10.00        2
# $10.99        2
# $109.99       1
# $11.99        3
# $12.99        3
# $13.99        2
# $14.00        1
# $14.99        9
# $15.46        1
# $15.99        1
# $154.99       1
# $16.99        2
# $17.99        2
# $18.99        1
#            ...
# $389.99       1
# $39.99        2
# $394.99       1
# $399.99      12
# $4.29         1
# $4.49         9
# $4.59         1
# $4.60         1
# $4.77         1
# $4.80         1
# $4.84         1
# $4.85         1
# $4.99        70
# $400.00       1
# $46.99        1
# $5.00         1
# $5.49         5
# $5.99        26
# $6.49         5
# $6.99        10
# $7.49         2
# $7.99         7
# $74.99        1
# $79.99        1
# $8.49         2
# $8.99         5
# $89.99        1
# $9.00         1
# $9.99        19
# 0          8905
# Length: 92, dtype: int64

# %%
playstore['Price'] = playstore['Price'].apply(lambda x: float(x.strip('$'))) # Rimuovo eventuale valuta
playstore[playstore['Price'] != 0]['Price'].head()
# Out:
# 290    4.99
# 291    4.99
# 427    3.99
# 478    1.49
# 479    2.99
# Name: Price, dtype: float64

# %%
playstore['Income'] = playstore['Price'] * playstore['Installs']
playstore[playstore['Price'] != 0][['Price','Installs','Income']].head()
# Out:
#      Price Installs  Income
# 290   4.99   100000  499000
# 291   4.99   100000  499000
# 427   3.99   100000  399000
# 478   1.49       50    74.5
# 479   2.99      100     299

# %% [markdown]
# # For each app, compute its minimum and maximum Sentiment_polarity

# %%
sent_max = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].max()).reset_index()
sent_min = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].min()).reset_index()
sent = pd.merge(sent_max,sent_min, on='App')
sent = sent.rename(columns={'Sentiment_Polarity_x':'Sentiment_Polarity_max','Sentiment_Polarity_y':'Sentiment_Polarity_min'})
sent
# Out:
#                                                     App  \
# 0                                 10 Best Foods for You
# 1                      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2                                                  11st
# 3                            1800 Contacts - Lens Store
# 4                       1LINE – One Line with One Touch
# 5      2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif
# 6                          21-Day Meditation Experience
# 7                   2Date Dating App, Love and matching
# 8                           2GIS: directory & navigator
# 9                                             2RedBeans
# 10                        2ndLine - Second Phone Number
# 11           30 Day Fitness Challenge - Workout at Home
# 12                              365Scores - Live Scores
# 13                   3D Blue Glass Water Keyboard Theme
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# 15                           3D Live Neon Weed Launcher
# 16                                           4 in a Row
# 17               4K Wallpapers and Ultra HD Backgrounds
# 18    591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價...
# 19                                           591房屋交易-香港
# 20                        7 Cups: Anxiety & Stress Chat
# 21                         7 Day Food Journal Challenge
# 22                                     7 Minute Workout
# 23                       7 Weeks - Habit & Goal Tracker
# 24                                          8 Ball Pool
# 25                               850 Sports News Digest
# 26                         8fit Workouts & Meal Planner
# 27                      95Live -SG#1 Live Streaming App
# 28                             A Call From Santa Claus!
# 29                              A Manual of Acupuncture
# ...                                                 ...
# 1044      Hole19: Golf GPS App, Rangefinder & Scorecard
# 1045  Home Decor Showpiece Art making: Medium Diffic...
# 1046                          Home Scouting® MLS Mobile
# 1047  Home Security Camera WardenCam - reuse old phones
# 1048                     Home Street – Home Design Game
# 1049                        Home Workout - No Equipment
# 1050                Home Workout for Men - Bodybuilding
# 1051  Home workouts - fat burning, abs, legs, arms,c...
# 1052                          HomeAway Vacation Rentals
# 1053                                           HomeWork
# 1054                         Homes.com 🏠 For Sale, Rent
# 1055                                         Homescapes
# 1056                     Homesnap Real Estate & Rentals
# 1057      Homestyler Interior Design & Decorating Ideas
# 1058                                   Homework Planner
# 1059                                  Honkai Impact 3rd
# 1060                      Hopper - Watch & Book Flights
# 1061  Horoscopes – Daily Zodiac Horoscope and Astrology
# 1062                              Horses Live Wallpaper
# 1063     Hostelworld: Hostels & Cheap Hotels Travel App
# 1064                               Hot Wheels: Race Off
# 1065                Hot or Not - Find someone right now
# 1066   HotelTonight: Book amazing deals at great hotels
# 1067                      Hotels Combined - Cheap deals
# 1068  Hotels.com: Book Hotel Rooms & Find Vacation D...
# 1069     Hotspot Shield Free VPN Proxy & Wi-Fi Security
# 1070                                            Hotstar
# 1071                     Hotwire Hotel & Car Rental App
# 1072                     Housing-Real Estate & Property
# 1073                        Houzz Interior Design Ideas
#
#       Sentiment_Polarity_max  Sentiment_Polarity_min
# 0                   1.000000               -0.800000
# 1                   0.910000               -0.112500
# 2                   1.000000               -1.000000
# 3                   0.838542               -0.300000
# 4                   1.000000               -0.825000
# 5                   1.000000               -0.800000
# 6                   0.587500               -0.265625
# 7                   1.000000               -0.645833
# 8                   1.000000               -0.375000
# 9                   1.000000               -0.800000
# 10                  1.000000               -0.781250
# 11                  0.900000               -0.500000
# 12                  1.000000                0.000000
# 13                       NaN                     NaN
# 14                       NaN                     NaN
# 15                  1.000000                0.136364
# 16                  1.000000               -0.800000
# 17                  0.750000               -0.700000
# 18                  0.700000               -0.300000
# 19                  0.700000               -0.077083
# 20                  0.812500               -0.172222
# 21                  0.343333                0.070000
# 22                  1.000000               -0.291667
# 23                  0.471212               -0.132576
# 24                  0.650000               -1.000000
# 25                  1.000000               -0.500000
# 26                  0.800000               -0.700000
# 27                  1.000000               -0.937500
# 28                  0.700000               -1.000000
# 29                       NaN                     NaN
# ...                      ...                     ...
# 1044                1.000000                0.000000
# 1045                0.780000               -1.000000
# 1046                1.000000               -0.800000
# 1047                1.000000               -0.800000
# 1048                0.600000               -0.750000
# 1049                1.000000               -0.016667
# 1050                1.000000                0.000000
# 1051                0.800000                0.050000
# 1052                     NaN                     NaN
# 1053                1.000000                1.000000
# 1054                1.000000               -0.600000
# 1055                0.503571               -0.197917
# 1056                1.000000               -0.600000
# 1057                0.988281               -0.400000
# 1058                0.718750               -0.208333
# 1059                0.775000               -0.237500
# 1060                0.761905               -0.937500
# 1061                1.000000               -0.040476
# 1062                1.000000               -0.656250
# 1063                1.000000               -1.000000
# 1064                0.391667               -0.625000
# 1065                     NaN                     NaN
# 1066                1.000000               -1.000000
# 1067                1.000000               -0.700000
# 1068                0.700000               -0.988281
# 1069                1.000000               -0.700000
# 1070                1.000000               -0.555556
# 1071                0.800000               -0.875000
# 1072                0.800000               -0.528571
# 1073                     NaN                     NaN
#
# [1074 rows x 3 columns]
