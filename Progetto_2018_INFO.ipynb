# %% [markdown]
# # Starting from the Google Play Store dataset

# %%
# Caricamento librerie d'interesse
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
#Lettura dataset googleplaystore
playstore = pd.read_csv('googleplaystore.csv')
playstore.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
#Lettura Last Updated
date_re = re.compile('(?P<month>\w+)\s(?P<day>\d+)\,\s(?P<year>\d+)')
month_diz = {'January': 1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,
         'November':11,'December':12}

def parse_date(data):
    dm = date_re.match(data)
    if dm:
        day = int(dm.group('day'))
        if (day < 10):
            day = '0' + str(day)   
        month = month_diz[dm.group('month')]   
        year = dm.group('year')
        return (str(day)+str(month)+str(year))
    else:
        return(np.nan)
    
playstore['Last_updated_parsed'] = pd.to_datetime(playstore['Last Updated'].apply(parse_date),format='%d%m%Y')
playstore[['Last Updated','Last_updated_parsed']].head()
# Out:
#        Last Updated Last_updated_parsed
# 0   January 7, 2018          2018-01-07
# 1  January 15, 2018          2018-01-15
# 2    August 1, 2018          2018-08-01
# 3      June 8, 2018          2018-06-08
# 4     June 20, 2018          2018-06-20

# %%
#Lettura dataset googleplaystore_user_reviews.csv
playstore_review = pd.read_csv('googleplaystore_user_reviews.csv')
playstore_review.head(2)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462

# %% [markdown]
# # Convert the app sizes to a number

# %%
#Ispezioni possibili moltiplicatori
print(playstore['Size'].isnull().any()) # No missing

def moltiplicatori_size(size):
    if (re.search('[a-zA-Z]', size)):
        size = re.sub('[\d\W]', '', size) #elimino tutto tranne lettere
    return(size)

list_molt = list(playstore['Size'].apply(moltiplicatori_size))

print(Counter(list_molt))
#Moltiplicatori sono k e M il '' si ha perchè un valore è pari a 1,000+ (niente moltiplicatore quindi)

playstore[playstore['Size'] == '1,000+'] # Valori traslati di una variabile -->INDEX = 10472
# Out:
# False
# Counter({'M': 8829, 'Varieswithdevice': 1695, 'k': 316, '1,000+': 1})
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Last_updated_parsed
# 10472       1.0.19  4.0 and up         NaN                 NaT

# %%
re_size = re.compile('^(?P<num>\d+\.?\d*)(?P<moltiplicatore>\w*)$')

def size_tonumber(app_size):
    r = re_size.match(app_size)
    if r:
        molt = r.group('moltiplicatore')
        if (molt == 'M'):
            molt = 1000000
        elif (molt == 'k'):
            molt = 1000
        app_size = float(r.group('num'))*molt
    return(app_size)

playstore['Size_num'] = playstore['Size'].apply(size_tonumber)
playstore[['Size','Size_num']].head()
# Out:
#    Size Size_num
# 0   19M  1.9e+07
# 1   14M  1.4e+07
# 2  8.7M  8.7e+06
# 3   25M  2.5e+07
# 4  2.8M  2.8e+06

# %% [markdown]
# # Convert the number of installs to a number

# %%
#Ispezione possibili valori attributo Installs
print(playstore['Installs'].isnull().any()) # No missing
print(playstore.groupby('Installs').size())

#presenza modalità 'Free'
playstore[playstore['Installs'] == 'Free'] # Valori traslati di una variabile, stesso record sopra
# Out:
# False
# Installs
# 0                    1
# 0+                  14
# 1+                  67
# 1,000+             907
# 1,000,000+        1579
# 1,000,000,000+      58
# 10+                386
# 10,000+           1054
# 10,000,000+       1252
# 100+               719
# 100,000+          1169
# 100,000,000+       409
# 5+                  82
# 5,000+             477
# 5,000,000+         752
# 50+                205
# 50,000+            479
# 50,000,000+        289
# 500+               330
# 500,000+           539
# 500,000,000+        72
# Free                 1
# dtype: int64
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Last_updated_parsed Size_num
# 10472       1.0.19  4.0 and up         NaN                 NaT   1,000+

# %%
def installs_tonumber(serie):
    if (re.search('\d',serie)):
        serie = int(re.sub('\D', '', serie)) #elimino tutti i caratteri esclusi i numerici
    return(serie)
        
playstore['Installs_num'] = playstore['Installs'].apply(installs_tonumber)
playstore[['Installs','Installs_num']].head()
# Out:
#       Installs Installs_num
# 0      10,000+        10000
# 1     500,000+       500000
# 2   5,000,000+      5000000
# 3  50,000,000+     50000000
# 4     100,000+       100000

# %% [markdown]
# # Transform “Varies with device” into a missing value

# %%
def missing(valore):
    if (valore == 'Varies with device'):
        valore = np.nan
    return(valore)

variabili = list(playstore.columns)
for variabile in variabili:
    playstore[variabile] = playstore[variabile].apply(missing)
    #print('Numero di missing value nella variabile ' + str(variabile) + ': ' + str(playstore[variabile].isnull().sum()))

# %% [markdown]
# # Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
#ispezione Android Ver
print(playstore['Android Ver'].isnull().any()) # Si missing

playstore.groupby('Android Ver').size()
#La presenza del trattino indica due versioni, l'assenza indica una sola versione a cui segue una stringa
# Out:
# True
# Android Ver
# 1.0 and up          2
# 1.5 and up         20
# 1.6 and up        116
# 2.0 and up         32
# 2.0.1 and up        7
# 2.1 and up        134
# 2.2 - 7.1.1         1
# 2.2 and up        244
# 2.3 and up        652
# 2.3.3 and up      281
# 3.0 and up        241
# 3.1 and up         10
# 3.2 and up         36
# 4.0 and up       1375
# 4.0.3 - 7.1.1       2
# 4.0.3 and up     1501
# 4.1 - 7.1.1         1
# 4.1 and up       2451
# 4.2 and up        394
# 4.3 and up        243
# 4.4 and up        980
# 4.4W and up        12
# 5.0 - 6.0           1
# 5.0 - 7.1.1         1
# 5.0 - 8.0           2
# 5.0 and up        601
# 5.1 and up         24
# 6.0 and up         60
# 7.0 - 7.1.1         1
# 7.0 and up         42
# 7.1 and up          3
# 8.0 and up          6
# dtype: int64

# %%
vers_re = re.compile('^(?P<vers>\d\.\d\.{0,1}\d{0,1})')

def version(ver):
    if ver is not np.nan:
        temp = ver.split('-')
        if len(temp)>1: #In caso di trattino e quindi due versioni
            ver = str(temp[1].strip()) #Rimuovo spazi iniziali e finali del secondo elemento della lista
        else: 
            ver = vers_re.match(ver).group('vers')
    return(ver)

playstore['Android_Ver_Clean'] = playstore['Android Ver'].apply(version)
print(playstore.groupby('Android_Ver_Clean').size())
playstore[['Android Ver','Android_Ver_Clean']].head()
# Out:
# Android_Ver_Clean
# 1.0         2
# 1.5        20
# 1.6       116
# 2.0        32
# 2.0.1       7
# 2.1       134
# 2.2       244
# 2.3       652
# 2.3.3     281
# 3.0       241
# 3.1        10
# 3.2        36
# 4.0      1375
# 4.0.3    1501
# 4.1      2451
# 4.2       394
# 4.3       243
# 4.4       992
# 5.0       601
# 5.1        24
# 6.0        61
# 7.0        42
# 7.1         3
# 7.1.1       6
# 8.0         8
# dtype: int64
#     Android Ver Android_Ver_Clean
# 0  4.0.3 and up             4.0.3
# 1  4.0.3 and up             4.0.3
# 2  4.0.3 and up             4.0.3
# 3    4.2 and up               4.2
# 4    4.4 and up               4.4

# %%
print(playstore['Current Ver'].isnull().any()) # Si missing
playstore.groupby('Current Ver').size()
# Out:
# True
# Current Ver
# 0.0.0.2                      1
# 0.0.1                       15
# 0.0.10                       1
# 0.0.2                        4
# 0.0.3                        2
# 0.0.4                        3
# 0.0.42                       1
# 0.0.44                       1
# 0.0.5                        3
# 0.0.52                       1
# 0.0.53                       1
# 0.0.6                        1
# 0.0.7                        3
# 0.0.73                       1
# 0.0.80                       1
# 0.0.9                        5
# 0.1                         13
# 0.1.0                        2
# 0.1.1                        3
# 0.1.10.0                     1
# 0.1.100944346                2
# 0.1.11                       1
# 0.1.187945513                1
# 0.1.2                        1
# 0.1.219                      1
# 0.1.22                       1
# 0.1.27                       1
# 0.1.5                        1
# 0.1.6                        1
# 0.1.7                        1
#                             ..
# v150                         1
# v2                           1
# v2.0.02_prod                 1
# v2.6.0                       1
# v2.7.10.6                    1
# v2.7.11.16                   1
# v2.7.11.27                   1
# v2.7.11.6                    2
# v2017.Dec.01.19              1
# v2018.Apr.12.16              1
# v2018.May.15.14              1
# v3                           1
# v3.1.1                       1
# v3.4.0-3                     1
# v3.7.93                      2
# v3.9f                        1
# v4.29.0.9                    1
# v4.30.0.8                    2
# v4.30.0.9                    1
# v5.4.3                       1
# v6.1                         1
# v6.6.0                       1
# v6.7.14                      1
# v67_slk3.0_20180115_01       1
# v7.0.02.3.0516.1_06_0713     1
# v7.0.7.1.0625.1_06_0629      1
# v7.0.9.1.0526.1_06_0704      1
# v8.0.1.8.0629.1              1
# v8[1.0.10]                   1
# version 0.994                1
# Length: 2831, dtype: int64

# %%
def current_ver_clean(ver):
    if ver is not np.nan:
        ver = re.sub('[^\d\.]', '', ver) #elimino tutte le lettere e i caratteri che non sono punti
        if (len(ver)>1 and ver[0] == '.'): #rimuovere il punto iniziale se presente
             ver = ver[1:]
        if ((ver == '') or (ver == '.')): #tali casi si presentano quando il valore è una parola
            return(np.nan)              
    return(ver)

playstore['Current_Ver_Clean'] = playstore['Current Ver'].apply(current_ver_clean)

print(playstore.groupby('Current_Ver_Clean').size())
playstore[['Current Ver','Current_Ver_Clean']].head()
# Out:
# Current_Ver_Clean
# 0.0.0.2              1
# 0.0.1               15
# 0.0.10               1
# 0.0.2                4
# 0.0.3                2
# 0.0.4                3
# 0.0.42               1
# 0.0.44               1
# 0.0.5                3
# 0.0.52               1
# 0.0.53               1
# 0.0.6                1
# 0.0.7                3
# 0.0.73               1
# 0.0.80               1
# 0.0.9                5
# 0.1                 13
# 0.1.0                2
# 0.1.1                3
# 0.1.10.0             1
# 0.1.100944346        2
# 0.1.11               1
# 0.1.187945513        1
# 0.1.2                1
# 0.1.219              1
# 0.1.22               1
# 0.1.27               1
# 0.1.5                1
# 0.1.6                1
# 0.1.7                1
#                     ..
# 9.2.4                1
# 9.3.1                3
# 9.3.3                1
# 9.3.52               1
# 9.3.5776             1
# 9.3.6                1
# 9.4.0                1
# 9.4.1.3              1
# 9.4.2                1
# 9.4.7.6              1
# 9.40.3               2
# 9.5.0                1
# 9.5.8                1
# 9.51.755029          1
# 9.55                 1
# 9.6.3                2
# 9.6.4                1
# 9.6.8                1
# 9.7.0                1
# 9.7.1                1
# 9.7.14188            2
# 9.7.6                1
# 9.7.753080           4
# 9.8.000000010492     2
# 9.8.000000010501     4
# 9.8.1.7425           2
# 9.8.376              1
# 9.9.0                2
# 9.9.1.1910           1
# 99.0.0.35.75         2
# Length: 2696, dtype: int64
#   Current Ver Current_Ver_Clean
# 0       1.0.0             1.0.0
# 1       2.0.0             2.0.0
# 2       1.2.4             1.2.4
# 3         NaN               NaN
# 4         1.1               1.1

# %% [markdown]
# # Remove the duplicates

# %%
#Da questo punto in poi conviene eliminare il record numero 10472 in quanto traslato
playstore = playstore.drop(10472)
#Per ogni app, viene/vengono selezionato/i i record che presentano meno recensioni in quanto meno recenti
playstore['Reviews'] = playstore['Reviews'].astype(int)
duplicati = playstore.sort_values(by=['App','Reviews'],ascending=True)
duplicati_cut = duplicati[duplicati.duplicated(subset=['App'], keep='last')]
duplicati_cut
# Out:
#                                                     App            Category  \
# 1393                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2322                         1800 Contacts - Lens Store             MEDICAL
# 2256                         2017 EMRA Antibiotic Guide             MEDICAL
# 1337                       21-Day Meditation Experience  HEALTH_AND_FITNESS
# 5415                            365Scores - Live Scores              SPORTS
# 2522                             420 BZ Budeze Delivery             MEDICAL
# 3953                                        8 Ball Pool              SPORTS
# 1675                                        8 Ball Pool                GAME
# 1703                                        8 Ball Pool                GAME
# 1755                                        8 Ball Pool                GAME
# 1844                                        8 Ball Pool                GAME
# 1970                                        8 Ball Pool                GAME
# 1296                       8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# 559                     95Live -SG#1 Live Streaming App              DATING
# 2301                            A Manual of Acupuncture             MEDICAL
# 920               A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 946               A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 977               A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 2515                                               AAFP             MEDICAL
# 3787                         ABC News - US & World News  NEWS_AND_MAGAZINES
# 4928                      AC - Tips & News for Android™  NEWS_AND_MAGAZINES
# 5448                          AP Mobile - Breaking News  NEWS_AND_MAGAZINES
# 2246                                       ASCCP Mobile             MEDICAL
# 2771                                               ASOS            SHOPPING
# 251                         Accounting App - Zoho Books            BUSINESS
# 5512  AccuWeather: Daily Forecast & Live Weather Rep...             WEATHER
# 1095                       Acorns - Invest Spare Change             FINANCE
# 250                                     AdWords Express            BUSINESS
# 2330                            Ada - Your Health Guide             MEDICAL
# 3895                               Adobe Acrobat Reader        PRODUCTIVITY
# ...                                                 ...                 ...
# 600                            iPair-Meet, Chat, Dating              DATING
# 346                        imo beta free calls and text       COMMUNICATION
# 2515           Medical      June 22, 2018             2.3.1    5.0 and up
# 3787  News & Magazines       June 6, 2018           3.19.11    5.0 and up
# 4928  News & Magazines       May 24, 2018            3.1.12    4.1 and up
# 5448  News & Magazines       May 25, 2017             4.4.3    4.0 and up
# 2246           Medical    October 3, 2016             2.1.1    2.2 and up
# 2771          Shopping      July 30, 2018             4.4.9    4.4 and up
# 251           Business     August 2, 2018            5.20.7    4.1 and up
# 5512           Weather     August 2, 2018               NaN           NaN
# 1095           Finance      July 31, 2018               NaN           NaN
# 250           Business      July 31, 2018           2.6.158    4.0 and up
# 2330           Medical      July 16, 2018            2.25.0    4.4 and up
# 3895      Productivity     April 17, 2018               NaN           NaN
# ...                ...                ...               ...           ...
# 600             Dating     August 2, 2018             5.0.8    4.1 and up
# 346      Communication       June 7, 2018  9.8.000000010492    4.0 and up
# 347      Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 4222     Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 383      Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 253           Business      July 16, 2018         4.3.0.508    4.4 and up
# 261           Business      July 16, 2018         4.3.0.508    4.4 and up
# 4322          Shopping     August 2, 2018             2.4.8    4.1 and up
# 525             Dating      July 24, 2018           3.8.75a  4.0.3 and up
# 558             Dating      July 24, 2018           3.8.75a  4.0.3 and up
# 4593      Productivity      July 18, 2018               NaN    5.0 and up
# 6194           Medical      July 23, 2018            3.52.0    5.0 and up
# 2331           Medical     August 6, 2018            3.52.1    5.0 and up
# 2618            Social   October 16, 2017             4.2.1    4.3 and up
# 3334             Tools     August 6, 2018           6.06.14    4.4 and up
# 1468      House & Home      July 16, 2018               NaN           NaN
# 4227            Action  November 14, 2017               NaN    2.3 and up
# 1659            Action  November 14, 2017               NaN    2.3 and up
# 1757            Action  November 14, 2017               NaN    2.3 and up
# 1735            Action  November 14, 2017               NaN    2.3 and up
# 1891            Action  November 14, 2017               NaN    2.3 and up
# 499             Dating       July 7, 2018             2.4.1    4.1 and up
# 2590            Social      July 26, 2018             7.3.1    4.1 and up
# 2964            Sports      July 25, 2018            6.17.2    4.4 and up
# 3014            Sports      July 25, 2018            6.17.2    4.4 and up
# 3055            Sports      July 25, 2018            6.17.2    4.4 and up
# 3063            Sports      July 25, 2018            6.17.2    4.4 and up
# 3103    Travel & Local     August 2, 2018               NaN           NaN
# 3118    Travel & Local     August 2, 2018               NaN           NaN
# 8291           Weather     August 6, 2018               NaN           NaN
#
#      Last_updated_parsed Size_num Installs_num Android_Ver_Clean  \
# 1393          2017-02-17  3.8e+06       500000             2.3.3
# 2322          2018-07-27  2.6e+07      1000000               5.0
# 2256          2017-01-27  3.8e+06         1000             4.0.3
# 1337          2018-08-02  1.5e+07       100000               4.1
# 5415          2018-07-29  2.5e+07     10000000               4.1
# 2522          2018-06-06  1.1e+07          100               4.1
# 3953          2018-07-31  5.2e+07    100000000             4.0.3
# 1675          2018-07-31  5.2e+07    100000000             4.0.3
# 1703          2018-07-31  5.2e+07    100000000             4.0.3
# 1755          2018-07-31  5.2e+07    100000000             4.0.3
# 1844          2018-07-31  5.2e+07    100000000             4.0.3
# 1970          2018-07-31  5.2e+07    100000000             4.0.3
# 1296          2018-07-11  6.7e+07     10000000               5.0
# 559           2018-08-01  1.5e+07      1000000               4.2
# 2301          2017-10-02  6.8e+07         1000               4.0
# 920           2018-07-16  1.9e+07      1000000               4.4
# 946           2018-07-16  1.9e+07      1000000               4.4
# 977           2018-07-16  1.9e+07      1000000               4.4
# 2515          2018-06-22  2.4e+07        10000               5.0
# 3787          2018-06-06  3.5e+07      1000000               5.0
# 4928          2018-05-24  1.4e+07      1000000               4.1
# 5448          2017-05-25  4.6e+06      1000000               4.0
# 2246          2016-10-03  2.5e+07        10000               2.2
# 2771          2018-07-30  2.2e+07     10000000               4.4
# 251           2018-08-02  8.5e+06       100000               4.1
# 5512          2018-08-02      NaN     50000000               NaN
# 1095          2018-07-31      NaN      1000000               NaN
# 250           2018-07-31  1.1e+07      1000000               4.0
# 2330          2018-07-16  1.4e+07      1000000               4.4
# 3895          2018-04-17      NaN    100000000               NaN
# ...                  ...      ...          ...               ...
# 600           2018-08-02  7.7e+07      5000000               4.1
# 346           2018-06-07  1.1e+07    100000000               4.0
# 347           2018-06-08  1.1e+07    500000000               4.0
# 4222          2018-06-08  1.1e+07    500000000               4.0
# 383           2018-06-08  1.1e+07    500000000               4.0
# 253           2018-07-16      NaN      1000000               4.4
# 261           2018-07-16      NaN      1000000               4.4
# 4322          2018-08-02    2e+07     50000000               4.1
# 525           2018-07-24  2.5e+07       100000             4.0.3
# 558           2018-07-24  2.5e+07       100000             4.0.3
# 4593          2018-07-18      NaN     50000000               5.0
# 6194          2018-07-23  3.5e+07      1000000               5.0
# 2331          2018-08-06  3.6e+07      1000000               5.0
# 2618          2017-10-16  3.4e+07     50000000               4.3
# 3334          2018-08-06  4.1e+06     10000000               4.4
# 1468          2018-07-16      NaN      1000000               NaN
# 4227          2017-11-14      NaN    100000000               2.3
# 1659          2017-11-14      NaN    100000000               2.3
# 1757          2017-11-14      NaN    100000000               2.3
# 1735          2017-11-14      NaN    100000000               2.3
# 1891          2017-11-14      NaN    100000000               2.3
# 499           2018-07-07  6.1e+06      1000000               4.1
# 2590          2018-07-26  2.8e+07     10000000               4.1
# 2964          2018-07-25  3.4e+07     10000000               4.4
# 3014          2018-07-25  3.4e+07     10000000               4.4
# 3055          2018-07-25  3.4e+07     10000000               4.4
# 3063          2018-07-25  3.4e+07     10000000               4.4
# 3103          2018-08-02      NaN     50000000               NaN
# 3118          2018-08-02      NaN     50000000               NaN
# 8291          2018-08-06  3.8e+07     10000000               NaN
#
#      Current_Ver_Clean
# 1393               1.9
# 2322             7.4.1
# 2256             1.0.5
# 1337             3.0.0
# 5415             5.5.9
# 2522             1.0.1
# 3953             4.0.0
# 1675             4.0.0
# 1703             4.0.0
# 1755             4.0.0
# 1844             4.0.0
# 1970             4.0.0
# 1296             3.5.0
# 559              8.7.2
# 2301            2.1.35
# 920              3.1.4
# 946              3.1.4
# 977              3.1.4
# 2515             2.3.1
# 3787           3.19.11
# 4928            3.1.12
# 5448             4.4.3
# 2246             2.1.1
# 2771             4.4.9
# 251             5.20.7
# 5512               NaN
# 1095               NaN
# 250            2.6.158
# 2330            2.25.0
# 3895               NaN
# ...                ...
# 600              5.0.8
# 346   9.8.000000010492
# 347   9.8.000000010501
# 4222  9.8.000000010501
# 383   9.8.000000010501
# 253          4.3.0.508
# 261          4.3.0.508
# 4322             2.4.8
# 525             3.8.75
# 558             3.8.75
# 4593               NaN
# 6194            3.52.0
# 2331            3.52.1
# 2618             4.2.1
# 3334           6.06.14
# 1468               NaN
# 4227               NaN
# 1659               NaN
# 1757               NaN
# 1735               NaN
# 1891               NaN
# 499              2.4.1
# 2590             7.3.1
# 2964            6.17.2
# 3014            6.17.2
# 3055            6.17.2
# 3063            6.17.2
# 3103               NaN
# 3118               NaN
# 8291               NaN
#
# [1181 rows x 18 columns]

# %%
playstore = playstore.drop(duplicati_cut.index)

# %% [markdown]
# # For each category, compute the number of apps

# %%
playstore.groupby('Category').size()
# Out:
# Category
# ART_AND_DESIGN           61
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     222
# BUSINESS                420
# COMICS                   56
# COMMUNICATION           315
# DATING                  170
# EDUCATION               105
# ENTERTAINMENT            86
# EVENTS                   64
# FAMILY                 1878
# FINANCE                 345
# FOOD_AND_DRINK          112
# GAME                    945
# HEALTH_AND_FITNESS      288
# HOUSE_AND_HOME           73
# LIBRARIES_AND_DEMO       84
# LIFESTYLE               369
# MAPS_AND_NAVIGATION     131
# MEDICAL                 395
# NEWS_AND_MAGAZINES      254
# PARENTING                60
# PERSONALIZATION         376
# PHOTOGRAPHY             281
# PRODUCTIVITY            374
# SHOPPING                202
# SOCIAL                  239
# SPORTS                  325
# TOOLS                   829
# TRAVEL_AND_LOCAL        219
# VIDEO_PLAYERS           164
# WEATHER                  79
# dtype: int64

# %% [markdown]
# # For each category, compute the average rating

# %%
playstore.groupby('Category')['Rating'].mean()
# Out:
# Category
# ART_AND_DESIGN         4.359322
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.344970
# BUSINESS               4.098479
# COMICS                 4.181481
# COMMUNICATION          4.121484
# DATING                 3.980451
# EDUCATION              4.349038
# ENTERTAINMENT          4.129070
# EVENTS                 4.435556
# FAMILY                 4.184150
# FINANCE                4.115563
# FOOD_AND_DRINK         4.171277
# GAME                   4.244432
# HEALTH_AND_FITNESS     4.243033
# HOUSE_AND_HOME         4.140984
# LIBRARIES_AND_DEMO     4.178125
# LIFESTYLE              4.093355
# MAPS_AND_NAVIGATION    4.036441
# MEDICAL                4.165862
# NEWS_AND_MAGAZINES     4.121569
# PARENTING              4.300000
# PERSONALIZATION        4.332215
# PHOTOGRAPHY            4.155894
# PRODUCTIVITY           4.183389
# SHOPPING               4.230556
# SOCIAL                 4.247291
# SPORTS                 4.216154
# TOOLS                  4.040278
# TRAVEL_AND_LOCAL       4.069519
# VIDEO_PLAYERS          4.044966
# WEATHER                4.243056
# Name: Rating, dtype: float64

# %% [markdown]
# # Create two dataframes: one for the genres and one bridging apps and genders. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
lista_app = []
lista_genres = []

for index,row in playstore.iterrows():
    l_generi = row['Genres'].split(';')
    for genre in l_generi:
        lista_genres.append(genre.strip())
        lista_app.append(row['App'])

app_genre = pd.DataFrame({'App' : lista_app, 'Genres_one' : lista_genres})
app_genre.head()
# Out:
#                                                  App    Genres_one
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 2                              Sketch - Draw & Paint  Art & Design
# 3              Pixel Draw - Number Art Coloring Book  Art & Design
# 4              Pixel Draw - Number Art Coloring Book    Creativity

# %%
genre_1 = []
genre_2 = []

for index,row in playstore.iterrows():
    l_generi = row['Genres'].split(';')
    genre_1.append(l_generi[0])
    if len(l_generi)<2:
        genre_2.append(np.nan)
    else:
        genre_2.append(l_generi[1])
        
df_2 = pd.DataFrame({'App' : playstore['App'], 'Genre_1' : genre_1, 'Genre_2' : genre_2})
df_2.head()
# Out:
#                                                  App       Genre_1     Genre_2
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design         NaN
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design         NaN
# 3                              Sketch - Draw & Paint  Art & Design         NaN
# 4              Pixel Draw - Number Art Coloring Book  Art & Design  Creativity
# 5                         Paper flowers instructions  Art & Design         NaN

# %%
df_genres = pd.DataFrame({'Genres' : list(set(lista_genres))})
df_genres.head()
# Out:
#                Genres
# 0       Communication
# 1  Action & Adventure
# 2              Beauty
# 3              Social
# 4         Photography

# %% [markdown]
# # For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
l_false = [False] * playstore.shape[0] #Lista di False
lista_generi = list(set(lista_genres)) #Lista con generi univoci

for genere in lista_generi:
    playstore[genere] = l_false #Inserisco in Playstore un attributo per ogni genere i cui valori sono tutti False
    
for index,row in playstore.iterrows():
    appoggio = row['Genres'].split(';')
    for genre in appoggio:
        playstore.at[index, genre.strip()] = True #Setto a True tutti i valori degli attributi riguardanti il genere/generi dell'app

playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme       ART_AND_DESIGN
# 31                                     Art Drawing Ideas       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size     Installs  Type Price Content Rating  \
# 0         4.1      159   19M      10,000+  Free     0       Everyone
# 2         4.7    87510  8.7M   5,000,000+  Free     0       Everyone
# 3         4.5   215644   25M  50,000,000+  Free     0           Teen
# 4         4.3      967  2.8M     100,000+  Free     0       Everyone
# 5         4.4      167  5.6M      50,000+  Free     0       Everyone
# 6         3.8      178   19M      50,000+  Free     0       Everyone
# 7         4.1    36815   29M   1,000,000+  Free     0       Everyone
# 8         4.4    13791   33M   1,000,000+  Free     0       Everyone
# 9         4.7      121  3.1M      10,000+  Free     0       Everyone
# 10        4.4    13880   28M   1,000,000+  Free     0       Everyone
# 11        4.4     8788   12M   1,000,000+  Free     0       Everyone
# 12        4.2    44829   20M  10,000,000+  Free     0           Teen
# 13        4.6     4326   21M     100,000+  Free     0       Everyone
# 14        4.4     1518   37M     100,000+  Free     0       Everyone
# 15        3.2       55  2.7M       5,000+  Free     0       Everyone
# 7                 Art & Design   ...      False  False  False        False
# 8                 Art & Design   ...      False  False  False        False
# 9      Art & Design;Creativity   ...      False  False  False        False
# 10                Art & Design   ...      False  False  False        False
# 11                Art & Design   ...      False  False  False        False
# 12                Art & Design   ...      False  False  False        False
# 13                Art & Design   ...      False  False  False        False
# 14                Art & Design   ...      False  False  False        False
# 15                Art & Design   ...      False  False  False        False
# 16                Art & Design   ...      False  False  False        False
# 17                Art & Design   ...      False  False  False        False
# 18                Art & Design   ...      False  False  False        False
# 19                Art & Design   ...      False  False  False        False
# 20                Art & Design   ...      False  False  False        False
# 21                Art & Design   ...      False  False  False        False
# 22                Art & Design   ...      False  False  False        False
# 24                Art & Design   ...      False  False  False        False
# 25                Art & Design   ...      False  False  False        False
# 26     Art & Design;Creativity   ...      False  False  False        False
# 27                Art & Design   ...      False  False  False        False
# 28                Art & Design   ...      False  False  False        False
# 29                Art & Design   ...      False  False  False        False
# 30                Art & Design   ...      False  False  False        False
# 31                Art & Design   ...      False  False  False        False
# ...                        ...   ...        ...    ...    ...          ...
# 10811          Auto & Vehicles   ...      False  False  False        False
# 10812                Education   ...      False  False  False        False
# 10813                 Business   ...      False  False  False        False
# 10814            Entertainment   ...      False  False  False        False
# 10815        Books & Reference   ...      False  False  False        False
# 10816                 Business   ...      False  False  False        False
# 10817                    Tools   ...      False  False  False        False
# 10818                  Finance   ...      False  False  False        False
# 10819        Books & Reference   ...      False  False  False        False
# 10820                Education   ...      False  False  False        False
# 10821            Entertainment   ...      False  False  False        False
# 10822             Productivity   ...      False  False  False         True
# 10823  Video Players & Editors   ...      False  False  False        False
# 10824                  Medical   ...      False  False  False        False
# 10825                   Social   ...      False  False  False        False
# 10826                   Social   ...      False  False  False        False
# 10827                Education   ...      False  False  False        False
# 10828                   Comics   ...      False  False  False        False
# 10829        Books & Reference   ...      False  False  False        False
# 10830         News & Magazines   ...      False  False  False        False
# 10831        Maps & Navigation   ...      False  False  False        False
# 10832                  Weather   ...      False  False  False        False
# 10833        Books & Reference   ...      False  False  False        False
# 10834                Education   ...      False  False  False        False
# 10835                 Business   ...      False  False  False        False
# 10836                Education   ...      False  False  False        False
# 10837                Education   ...      False  False  False        False
# 10838                  Medical   ...      False  False  False        False
# 10839        Books & Reference   ...      False  False  False        False
# 10840                Lifestyle   ...      False  False  False        False
#
#       Books & Reference Sports Casino Video Players & Editors  Pretend Play  \
# 0                 False  False  False                   False         False
# 2                 False  False  False                   False         False
# 3                 False  False  False                   False         False
# 4                 False  False  False                   False         False
# 5                 False  False  False                   False         False
# 6                 False  False  False                   False         False
# 7                 False  False  False                   False         False
# 8                 False  False  False                   False         False
# 9                 False  False  False                   False         False
# 10                False  False  False                   False         False
# 11                False  False  False                   False         False
# 12                False  False  False                   False         False
# 13                False  False  False                   False         False
# 14                False  False  False                   False         False
# 15                False  False  False                   False         False
# 16                False  False  False                   False         False
# 17                False  False  False                   False         False
# 18                False  False  False                   False         False
# 19                False  False  False                   False         False
# 20                False  False  False                   False         False
# 21                False  False  False                   False         False
# 22                False  False  False                   False         False
# 24                False  False  False                   False         False
# 25                False  False  False                   False         False
# 26                False  False  False                   False         False
# 27                False  False  False                   False         False
# 28                False  False  False                   False         False
# 29                False  False  False                   False         False
# 30                False  False  False                   False         False
# 31                False  False  False                   False         False
# ...                 ...    ...    ...                     ...           ...
# 10811             False  False  False                   False         False
# 10812             False  False  False                   False         False
# 10813             False  False  False                   False         False
# 10814             False  False  False                   False         False
# 10815              True  False  False                   False         False
# 10816             False  False  False                   False         False
# 10817             False  False  False                   False         False
# 10818             False  False  False                   False         False
# 10819              True  False  False                   False         False
# 10820             False  False  False                   False         False
# 10821             False  False  False                   False         False
# 10822             False  False  False                   False         False
# 10823             False  False  False                    True         False
# 10824             False  False  False                   False         False
# 10825             False  False  False                   False         False
# 10826             False  False  False                   False         False
# 10827             False  False  False                   False         False
# 10828             False  False  False                   False         False
# 10829              True  False  False                   False         False
# 10830             False  False  False                   False         False
# 10831             False  False  False                   False         False
# 10832             False  False  False                   False         False
# 10833              True  False  False                   False         False
# 10834             False  False  False                   False         False
# 10835             False  False  False                   False         False
# 10836             False  False  False                   False         False
# 10837             False  False  False                   False         False
# 10838             False  False  False                   False         False
# 10839              True  False  False                   False         False
# 10840             False  False  False                   False         False
#
#        Comics
# 0       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# ...       ...
# 10811   False
# 10812   False
# 10813   False
# 10814   False
# 10815   False
# 10816   False
# 10817   False
# 10818   False
# 10819   False
# 10820   False
# 10821   False
# 10822   False
# 10823   False
# 10824   False
# 10825   False
# 10826   False
# 10827   False
# 10828    True
# 10829   False
# 10830   False
# 10831   False
# 10832   False
# 10833   False
# 10834   False
# 10835   False
# 10836   False
# 10837   False
# 10838   False
# 10839   False
# 10840   False
#
# [9659 rows x 71 columns]

# %% [markdown]
# # For each genre, compute the average rating. What is the genre with highest average?

# %%
dff = pd.merge(app_genre, playstore, on='App')
dff.groupby('Genres_one')['Rating'].mean()
# Out:
# Genres_one
# Action                     4.247697
# Action & Adventure         4.288542
# Adventure                  4.191026
# Arcade                     4.277838
# Art & Design               4.350000
# Auto & Vehicles            4.190411
# Beauty                     4.278571
# Board                      4.291228
# Books & Reference          4.343275
# Brain Games                4.358065
# Business                   4.098479
# Card                       4.082609
# Casino                     4.286486
# Casual                     4.141014
# Comics                     4.181481
# Communication              4.121790
# Creativity                 4.306250
# Dating                     3.980451
# Education                  4.290290
# Educational                4.100000
# Entertainment              4.093028
# Events                     4.435556
# Finance                    4.115563
# Food & Drink               4.171277
# Health & Fitness           4.243496
# House & Home               4.140984
# Libraries & Demo           4.178125
# Lifestyle                  4.094040
# Maps & Navigation          4.036441
# Medical                    4.165862
# Music                      4.219048
# Music & Audio              4.300000
# Music & Video              4.229032
# News & Magazines           4.121569
# Parenting                  4.300000
# Personalization            4.332215
# Photography                4.155894
# Pretend Play               4.238235
# Productivity               4.183389
# Puzzle                     4.370732
# Racing                     4.174757
# Role Playing               4.272072
# Shopping                   4.230556
# Simulation                 4.154500
# Social                     4.247291
# Sports                     4.225185
# Strategy                   4.227368
# Tools                      4.040278
# Travel & Local             4.069519
# Trivia                     4.039286
# Video Players & Editors    4.044667
# Weather                    4.243056
# Word                       4.318182
# Name: Rating, dtype: float64

# %%
#Rating medio massimo
dff.groupby('Genres_one')['Rating'].mean().idxmax()
# Out:
# 'Events'

# %% [markdown]
# # For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
#ispezione price
print(playstore.Price.isnull().any())#no missing
playstore.groupby('Price').size()
#quindi il valore o è 0 o ha come valuta il $
# Out:
# False
# Price
# $0.99       145
# $1.00         3
# $1.04         1
# $1.20         1
# $1.26         1
# $1.29         1
# $1.49        46
# $1.50         1
# $1.59         1
# $1.61         1
# $1.70         2
# $1.75         1
# $1.76         1
# $1.96         1
# $1.97         1
# $1.99        73
# $10.00        2
# $10.99        2
# $109.99       1
# $11.99        3
# $12.99        3
# $13.99        2
# $14.00        1
# $14.99        9
# $15.46        1
# $15.99        1
# $154.99       1
# $16.99        2
# $17.99        2
# $18.99        1
#            ...
# $389.99       1
# $39.99        2
# $394.99       1
# $399.99      12
# $4.29         1
# $4.49         9
# $4.59         1
# $4.60         1
# $4.77         1
# $4.80         1
# $4.84         1
# $4.85         1
# $4.99        70
# $400.00       1
# $46.99        1
# $5.00         1
# $5.49         5
# $5.99        26
# $6.49         5
# $6.99        10
# $7.49         2
# $7.99         7
# $74.99        1
# $79.99        1
# $8.49         2
# $8.99         5
# $89.99        1
# $9.00         1
# $9.99        19
# 0          8905
# Length: 92, dtype: int64

# %%
playstore['Price_number'] = playstore['Price'].apply(lambda x: float(x.strip('$'))) #Rimuovo eventuale valuta
playstore[playstore['Price'] != '0'][['Price','Price_number']].head()#verifica se prezzo è trasformato correttamento (0 escluso)
# Out:
#      Price  Price_number
# 290  $4.99          4.99
# 291  $4.99          4.99
# 427  $3.99          3.99
# 478  $1.49          1.49
# 479  $2.99          2.99

# %%
playstore['Income'] = playstore['Price_number'] * playstore['Installs_num']
playstore[playstore['Price'] != '0'][['Price','Installs','Income']].head()
# Out:
#      Price  Installs  Income
# 290  $4.99  100,000+  499000
# 291  $4.99  100,000+  499000
# 427  $3.99  100,000+  399000
# 478  $1.49       50+    74.5
# 479  $2.99      100+     299

# %% [markdown]
# # For each app, compute its minimum and maximum Sentiment_polarity

# %%
sent_max = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].max()).reset_index()
sent_min = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].min()).reset_index()
sent = pd.merge(sent_max,sent_min, on='App')
sent.rename(columns={'Sentiment_Polarity_x':'Sentiment_Polarity_max','Sentiment_Polarity_y':'Sentiment_Polarity_min'}).head()
# Out:
#                                 App  Sentiment_Polarity_max  \
# 0             10 Best Foods for You                1.000000
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.910000
# 2                              11st                1.000000
# 3        1800 Contacts - Lens Store                0.838542
# 4   1LINE – One Line with One Touch                1.000000
#
#    Sentiment_Polarity_min
# 0                 -0.8000
# 1                 -0.1125
# 2                 -1.0000
# 3                 -0.3000
# 4                 -0.8250
