# %% [markdown]
# # Starting from the Google Play Store dataset

# %%
# Caricamento librerie d'interesse
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
#Lettura dataset googleplaystore
playstore = pd.read_csv('googleplaystore.csv')
playstore.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
#Lettura Last Updated
date_re = re.compile('(?P<month>\w+)\s(?P<day>\d+)\,\s(?P<year>\d+)')
month_diz = {'January': 1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,
         'November':11,'December':12}

def parse_date(data):
    dm = date_re.match(data)
    if dm:
        day = int(dm.group('day'))
        if (day < 10):
            day = '0' + str(day)   
        month = month_diz[dm.group('month')]   
        year = dm.group('year')
        return (str(day)+str(month)+str(year))
    else:
        return(np.nan)
    
playstore['Last_updated_parsed'] = pd.to_datetime(playstore['Last Updated'].apply(parse_date),format='%d%m%Y')
playstore[['Last Updated','Last_updated_parsed']].head()
# Out:
#        Last Updated Last_updated_parsed
# 0   January 7, 2018          2018-01-07
# 1  January 15, 2018          2018-01-15
# 2    August 1, 2018          2018-08-01
# 3      June 8, 2018          2018-06-08
# 4     June 20, 2018          2018-06-20

# %%
#missing value
playstore.isnull().any()
# Out:
# App                    False
# Category               False
# Rating                  True
# Reviews                False
# Size                   False
# Installs               False
# Type                    True
# Price                  False
# Content Rating          True
# Genres                 False
# Last Updated           False
# Current Ver             True
# Android Ver             True
# Last_updated_parsed     True
# dtype: bool

# %%
#Lettura dataset googleplaystore_user_reviews.csv
playstore_review = pd.read_csv('googleplaystore_user_reviews.csv')
playstore_review.head(2)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462

# %% [markdown]
# # Convert the app sizes to a number

# %%
#Ispezioni possibili moltiplicatori
def moltiplicatori_size(size):
    size = re.sub('[\d\W]', '', size) #elimino tutto tranne lettere
    return(size)

list_molt = list(playstore['Size'].apply(moltiplicatori_size))
print(Counter(list_molt))
#Moltiplicatori sono k e M il '' si ha perchè un valore era pari a 1,000+ (niente moltiplicatore quindi)
playstore[playstore['Size'] == '1,000+'] # Valori traslati di una variabile
# Out:
# Counter({'M': 8829, 'Varieswithdevice': 1695, 'k': 316, '': 1})
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Last_updated_parsed
# 10472       1.0.19  4.0 and up         NaN                 NaT

# %%
re_size = re.compile('^(?P<num>\d+\.?\d*)(?P<moltiplicatore>\w*)$')

def app_tonumber(app_size):
    r = re_size.match(app_size)
    if r:
        molt = r.group('moltiplicatore')
        if (molt == 'M'):
            molt = 1000000
        elif (molt == 'k'):
            molt = 1000
        app_size = float(r.group('num'))*molt
    return(app_size)

playstore['Size_num'] = playstore['Size'].apply(app_tonumber)
playstore[['Size','Size_num']].head()
# Out:
#    Size Size_num
# 0   19M  1.9e+07
# 1   14M  1.4e+07
# 2  8.7M  8.7e+06
# 3   25M  2.5e+07
# 4  2.8M  2.8e+06

# %% [markdown]
# # Convert the number of installs to a number

# %%
#Ispezione possibili valori attributo Installs
playstore.groupby('Installs').size()
#presenza modalità 'Free'
playstore[playstore['Installs'] == 'Free'] # Valori traslati di una variabile, stesso record sopra
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Last_updated_parsed Size_num
# 10472       1.0.19  4.0 and up         NaN                 NaT   1,000+

# %%
num_re = re.compile('\d') # Escludere presenza modalità Free

def installs_tonumber(serie):
    if num_re.match(serie):
        serie = int(re.sub('\D', '', serie)) #elimino tutti i caratteri esclusi i numerici
    return(serie)
        
playstore['Installs_num'] = playstore['Installs'].apply(installs_tonumber)
playstore[['Installs','Installs_num']].head()
# Out:
#       Installs Installs_num
# 0      10,000+        10000
# 1     500,000+       500000
# 2   5,000,000+      5000000
# 3  50,000,000+     50000000
# 4     100,000+       100000

# %% [markdown]
# # Transform “Varies with device” into a missing value

# %%
variabili = list(playstore.columns)

def missing(valore):
    if (valore == 'Varies with device'):
        valore = np.nan
    return(valore)

for variabile in variabili:
    playstore[variabile] = playstore[variabile].apply(missing)
    #print('Numero di missing value nella variabile ' + str(variabile) + ': ' + str(playstore[variabile].isnull().sum()))

# %% [markdown]
# # Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
#ispezione Android Ver
playstore.groupby('Android Ver').size()
#La presenza del trattino indica due versioni, l'assenza una sola accompagnata da una stringa
# Out:
# Android Ver
# 1.0 and up          2
# 1.5 and up         20
# 1.6 and up        116
# 2.0 and up         32
# 2.0.1 and up        7
# 2.1 and up        134
# 2.2 - 7.1.1         1
# 2.2 and up        244
# 2.3 and up        652
# 2.3.3 and up      281
# 3.0 and up        241
# 3.1 and up         10
# 3.2 and up         36
# 4.0 and up       1375
# 4.0.3 - 7.1.1       2
# 4.0.3 and up     1501
# 4.1 - 7.1.1         1
# 4.1 and up       2451
# 4.2 and up        394
# 4.3 and up        243
# 4.4 and up        980
# 4.4W and up        12
# 5.0 - 6.0           1
# 5.0 - 7.1.1         1
# 5.0 - 8.0           2
# 5.0 and up        601
# 5.1 and up         24
# 6.0 and up         60
# 7.0 - 7.1.1         1
# 7.0 and up         42
# 7.1 and up          3
# 8.0 and up          6
# dtype: int64

# %%
vers_re = re.compile('^(?P<vers>\d\.\d\.{0,1}\d{0,1})')

def version(ver):
    if ver is not np.nan:
        temp = ver.split('-')
        if len(temp)>1: #In caso di trattino e quindi due versioni
            ver = str(temp[1].strip()) #Rimuovo spazi iniziali e finali del secondo elemento della lista
        else: 
            ver = vers_re.match(ver).group('vers')
    return(ver)

playstore['Android_Ver_Clean'] = playstore['Android Ver'].apply(version)
playstore[['Android Ver','Android_Ver_Clean']].head()
# Out:
#     Android Ver Android_Ver_Clean
# 0  4.0.3 and up             4.0.3
# 1  4.0.3 and up             4.0.3
# 2  4.0.3 and up             4.0.3
# 3    4.2 and up               4.2
# 4    4.4 and up               4.4

# %%
playstore.groupby('Current Ver').size()
# Out:
# Current Ver
# 0.0.0.2                      1
# 0.0.1                       15
# 0.0.10                       1
# 0.0.2                        4
# 0.0.3                        2
# 0.0.4                        3
# 0.0.42                       1
# 0.0.44                       1
# 0.0.5                        3
# 0.0.52                       1
# 0.0.53                       1
# 0.0.6                        1
# 0.0.7                        3
# 0.0.73                       1
# 0.0.80                       1
# 0.0.9                        5
# 0.1                         13
# 0.1.0                        2
# 0.1.1                        3
# 0.1.10.0                     1
# 0.1.100944346                2
# 0.1.11                       1
# 0.1.187945513                1
# 0.1.2                        1
# 0.1.219                      1
# 0.1.22                       1
# 0.1.27                       1
# 0.1.5                        1
# 0.1.6                        1
# 0.1.7                        1
#                             ..
# v150                         1
# v2                           1
# v2.0.02_prod                 1
# v2.6.0                       1
# v2.7.10.6                    1
# v2.7.11.16                   1
# v2.7.11.27                   1
# v2.7.11.6                    2
# v2017.Dec.01.19              1
# v2018.Apr.12.16              1
# v2018.May.15.14              1
# v3                           1
# v3.1.1                       1
# v3.4.0-3                     1
# v3.7.93                      2
# v3.9f                        1
# v4.29.0.9                    1
# v4.30.0.8                    2
# v4.30.0.9                    1
# v5.4.3                       1
# v6.1                         1
# v6.6.0                       1
# v6.7.14                      1
# v67_slk3.0_20180115_01       1
# v7.0.02.3.0516.1_06_0713     1
# v7.0.7.1.0625.1_06_0629      1
# v7.0.9.1.0526.1_06_0704      1
# v8.0.1.8.0629.1              1
# v8[1.0.10]                   1
# version 0.994                1
# Length: 2831, dtype: int64

# %%
def current_ver_clean(ver):
    if ver is not np.nan:
        ver = re.sub('[^\d\.]', '', ver)
    return(ver)
playstore['Current_Ver_Clean'] = playstore['Current Ver'].apply(current_ver_clean)
playstore[['Current Ver','Current_Ver_Clean']]
playstore.groupby('Current_Ver_Clean').size()
# Out:
# Current_Ver_Clean
#                     16
# .                    1
# .1.0                 1
# .2                   1
# .2014.002            1
# .2918664             1
# .6                   1
# 0.0.0.2              1
# 0.0.1               15
# 0.0.10               1
# 0.0.2                4
# 0.0.3                2
# 0.0.4                3
# 0.0.42               1
# 0.0.44               1
# 0.0.5                3
# 0.0.52               1
# 0.0.53               1
# 0.0.6                1
# 0.0.7                3
# 0.0.73               1
# 0.0.80               1
# 0.0.9                5
# 0.1                 13
# 0.1.0                2
# 0.1.1                3
# 0.1.10.0             1
# 0.1.100944346        2
# 0.1.11               1
# 0.1.187945513        1
#                     ..
# 9.2.4                1
# 9.3.1                3
# 9.3.3                1
# 9.3.52               1
# 9.3.5776             1
# 9.3.6                1
# 9.4.0                1
# 9.4.1.3              1
# 9.4.2                1
# 9.4.7.6              1
# 9.40.3               2
# 9.5.0                1
# 9.5.8                1
# 9.51.755029          1
# 9.55                 1
# 9.6.3                2
# 9.6.4                1
# 9.6.8                1
# 9.7.0                1
# 9.7.1                1
# 9.7.14188            2
# 9.7.6                1
# 9.7.753080           4
# 9.8.000000010492     2
# 9.8.000000010501     4
# 9.8.1.7425           2
# 9.8.376              1
# 9.9.0                2
# 9.9.1.1910           1
# 99.0.0.35.75         2
# Length: 2701, dtype: int64

# %% [markdown]
# # Remove the duplicates

# %%
#Per ogni app, viene/vengono selezionato/i i record che presentano meno recensioni in quanto meno recenti
duplicati_cut = playstore[playstore.duplicated(subset=['App'], keep='first')].sort_values(by=['App','Reviews'])
duplicati_cut
# Out:
#                                                      App            Category  \
# 1407                               10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                          1800 Contacts - Lens Store             MEDICAL
# 2385                          2017 EMRA Antibiotic Guide             MEDICAL
# 1434                        21-Day Meditation Experience  HEALTH_AND_FITNESS
# 5415                             365Scores - Live Scores              SPORTS
# 7035                              420 BZ Budeze Delivery             MEDICAL
# 3953                                         8 Ball Pool              SPORTS
# 1703                                         8 Ball Pool                GAME
# 1755                                         8 Ball Pool                GAME
# 1844                                         8 Ball Pool                GAME
# 1970                                         8 Ball Pool                GAME
# 1871                                         8 Ball Pool                GAME
# 1324                        8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# 662                      95Live -SG#1 Live Streaming App              DATING
# 2402                             A Manual of Acupuncture             MEDICAL
# 946                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 977                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 4991               A&E - Watch Full Episodes of TV Shows              FAMILY
# 10768                                               AAFP             MEDICAL
# 3806                          ABC News - US & World News  NEWS_AND_MAGAZINES
# 4928                       AC - Tips & News for Android™  NEWS_AND_MAGAZINES
# 5448                           AP Mobile - Breaking News  NEWS_AND_MAGAZINES
# 2378                                        ASCCP Mobile             MEDICAL
# 2800                                                ASOS            SHOPPING
# 280                          Accounting App - Zoho Books            BUSINESS
# 5512   AccuWeather: Daily Forecast & Live Weather Rep...             WEATHER
# 1143                        Acorns - Invest Spare Change             FINANCE
# 279                                      AdWords Express            BUSINESS
# 2488                             Ada - Your Health Guide             MEDICAL
# 3895                                Adobe Acrobat Reader        PRODUCTIVITY
# ...                                                  ...                 ...
# 695                             iPair-Meet, Chat, Dating              DATING
# 4123                        imo beta free calls and text       COMMUNICATION
# 4222                       imo free video calls and chat       COMMUNICATION
# 383                        imo free video calls and chat       COMMUNICATION
# 465                        imo free video calls and chat       COMMUNICATION
# 261                            join.me - Simple Meetings            BUSINESS
# 282                            join.me - Simple Meetings            BUSINESS
# 4322    letgo: Buy & Sell Used Stuff, Cars & Real Estate            SHOPPING
# 558    muzmatch: Muslim & Arab Singles, Marriage & Da...              DATING
# 673    muzmatch: Muslim & Arab Singles, Marriage & Da...              DATING
# 4593                                              myAT&T        PRODUCTIVITY
# 6194   mySugr: the blood sugar tracker made just for you             MEDICAL
# 2367   mySugr: the blood sugar tracker made just for you             MEDICAL
# 2618              ooVoo Video Calls, Messaging & Stories              SOCIAL
# 10473                            osmino Wi-Fi: free WiFi               TOOLS
# 5664       realestate.com.au - Buy, Rent & Sell Property      HOUSE_AND_HOME
# 4227                                          slither.io                GAME
# 1757                                          slither.io                GAME
# 1735                                          slither.io                GAME
# 1891                                          slither.io                GAME
# 1921                                          slither.io                GAME
# 565                       stranger chat - anonymous chat              DATING
# 2637                         textPlus: Free Text & Calls              SOCIAL
# 3014   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3055   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3063   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3085   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3118                            trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3202                            trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 8291                      wetter.com - Weather and Radar             WEATHER
#
#        Rating   Reviews  Size      Installs  Type   Price Content Rating  \
# 1407      4.0      2490  3.8M      500,000+  Free       0   Everyone 10+
# 2543      4.7     23160   26M    1,000,000+  Free       0       Everyone
# 2385      4.4        12  3.8M        1,000+  Paid  $16.99       Everyone
# 1434      4.4     11506   15M      100,000+  Free       0       Everyone
# 5415      4.6    666246   25M   10,000,000+  Free       0       Everyone
# 7035      5.0         2   11M          100+  Free       0     Mature 17+
# 3953      4.5  14184910   52M  100,000,000+  Free       0       Everyone
# 1703      4.5  14198602   52M  100,000,000+  Free       0       Everyone
# 1755      4.5  14200344   52M  100,000,000+  Free       0       Everyone
# 1844      4.5  14200550   52M  100,000,000+  Free       0       Everyone
# 1970      4.5  14201604   52M  100,000,000+  Free       0       Everyone
# 1871      4.5  14201891   52M  100,000,000+  Free       0       Everyone
# 1324      4.6    115721   67M   10,000,000+  Free       0       Everyone
# 662       4.1      4954   15M    1,000,000+  Free       0           Teen
# 2402      3.5       214   68M        1,000+  Paid  $33.99       Everyone
# 946       4.0     29706   19M    1,000,000+  Free       0           Teen
# 977       4.0     29706   19M    1,000,000+  Free       0           Teen
# 4991      4.0     29708   19M    1,000,000+  Free       0           Teen
# 10768     3.8        63   24M       10,000+  Free       0       Everyone
# 3806      4.0     18976   35M    1,000,000+  Free       0   Everyone 10+
# 4928      4.2     23291   14M    1,000,000+  Free       0   Everyone 10+
# 5448      4.5     76616  4.6M    1,000,000+  Free       0   Everyone 10+
# 2378      4.5        63   25M       10,000+  Paid   $9.99       Everyone
# 2800      4.7    181823   22M   10,000,000+  Free       0       Everyone
# 280       4.5      3079  8.5M      100,000+  Free       0       Everyone
# 5512      4.4   2052407   NaN   50,000,000+  Free       0       Everyone
# 1143      4.3     45962   NaN    1,000,000+  Free       0       Everyone
# 279       4.1      7149   11M    1,000,000+  Free       0       Everyone
# 2488      4.7     87418   14M    1,000,000+  Free       0       Everyone
# 3895      4.3   3014548   NaN  100,000,000+  Free       0       Everyone
# ...       ...       ...   ...           ...   ...     ...            ...
# 695       4.5    182986   77M    5,000,000+  Free       0     Mature 17+
# 4123      4.3    659395   11M  100,000,000+  Free       0       Everyone
# 4222      4.3   4785892   11M  500,000,000+  Free       0       Everyone
# 383       4.3   4785988   11M  500,000,000+  Free       0       Everyone
# 465       4.3   4785988   11M  500,000,000+  Free       0       Everyone
# 261       4.0      6989   NaN    1,000,000+  Free       0       Everyone
# 282       4.0      6989   NaN    1,000,000+  Free       0       Everyone
# 4322      4.5    972256   20M   50,000,000+  Free       0           Teen
# 558       3.8      5164   25M      100,000+  Free       0     Mature 17+
# 673       3.8      5168   25M      100,000+  Free       0     Mature 17+
# 4593      3.7     80816   NaN   50,000,000+  Free       0       Everyone
# 6194      4.6     21187   35M    1,000,000+  Free       0       Everyone
# 2367      4.6     21189   36M    1,000,000+  Free       0       Everyone
# 2618      4.3   1157003   34M   50,000,000+  Free       0       Everyone
# 10473     4.2    134203  4.1M   10,000,000+  Free       0       Everyone
# 5664      3.8     14657   NaN    1,000,000+  Free       0       Everyone
# 4227      4.4   5231553   NaN  100,000,000+  Free       0       Everyone
# 1757      4.4   5234810   NaN  100,000,000+  Free       0       Everyone
# 1735      4.4   5234825   NaN  100,000,000+  Free       0       Everyone
# 1891      4.4   5235294   NaN  100,000,000+  Free       0       Everyone
# 1921      4.4   5235294   NaN  100,000,000+  Free       0       Everyone
# 565       3.5     13204  6.1M    1,000,000+  Free       0     Mature 17+
# 2637      4.1    382121   28M   10,000,000+  Free       0       Everyone
# 3014      4.4    133825   34M   10,000,000+  Free       0   Everyone 10+
# 3055      4.4    133833   34M   10,000,000+  Free       0   Everyone 10+
# 3063      4.4    133833   34M   10,000,000+  Free       0   Everyone 10+
# 3085      4.4    133833   34M   10,000,000+  Free       0   Everyone 10+
# 3118      4.2    219848   NaN   50,000,000+  Free       0       Everyone
# 3202      4.2    219848   NaN   50,000,000+  Free       0       Everyone
# 8291      4.2    189310   38M   10,000,000+  Free       0       Everyone
#
#                  Genres       Last Updated       Current Ver   Android Ver  \
# 1407   Health & Fitness  February 17, 2017               1.9  2.3.3 and up
# 2543            Medical      July 27, 2018             7.4.1    5.0 and up
# 2385            Medical   January 27, 2017             1.0.5  4.0.3 and up
# 1434   Health & Fitness     August 2, 2018             3.0.0    4.1 and up
# 5415             Sports      July 29, 2018             5.5.9    4.1 and up
# 7035            Medical       June 6, 2018             1.0.1    4.1 and up
# 3953             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1703             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1755             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1844             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1970             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1871             Sports      July 31, 2018             4.0.0  4.0.3 and up
# 1324   Health & Fitness      July 11, 2018             3.5.0    5.0 and up
# 662              Dating     August 1, 2018             8.7.2    4.2 and up
# 2402            Medical    October 2, 2017            2.1.35    4.0 and up
# 946       Entertainment      July 16, 2018             3.1.4    4.4 and up
# 977       Entertainment      July 16, 2018             3.1.4    4.4 and up
# 4991      Entertainment      July 16, 2018             3.1.4    4.4 and up
# 10768           Medical      June 22, 2018             2.3.1    5.0 and up
# 3806   News & Magazines       June 6, 2018           3.19.11    5.0 and up
# 4928   News & Magazines       May 24, 2018            3.1.12    4.1 and up
# 5448   News & Magazines       May 25, 2017             4.4.3    4.0 and up
# 2378            Medical    October 3, 2016             2.1.1    2.2 and up
# 2800           Shopping      July 30, 2018             4.4.9    4.4 and up
# 280            Business     August 2, 2018            5.20.7    4.1 and up
# 5512            Weather     August 2, 2018               NaN           NaN
# 1143            Finance      July 31, 2018               NaN           NaN
# 279            Business      July 31, 2018           2.6.158    4.0 and up
# 2488            Medical      July 16, 2018            2.25.0    4.4 and up
# 3895       Productivity     April 17, 2018               NaN           NaN
# ...                 ...                ...               ...           ...
# 695              Dating     August 2, 2018             5.0.8    4.1 and up
# 4123      Communication       June 7, 2018  9.8.000000010492    4.0 and up
# 4222      Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 383       Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 465       Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 261            Business      July 16, 2018         4.3.0.508    4.4 and up
# 282            Business      July 16, 2018         4.3.0.508    4.4 and up
# 4322           Shopping     August 2, 2018             2.4.8    4.1 and up
# 558              Dating      July 24, 2018           3.8.75a  4.0.3 and up
# 673              Dating      July 24, 2018           3.8.75a  4.0.3 and up
# 4593       Productivity      July 18, 2018               NaN    5.0 and up
# 6194            Medical      July 23, 2018            3.52.0    5.0 and up
# 2367            Medical     August 6, 2018            3.52.1    5.0 and up
# 2618             Social   October 16, 2017             4.2.1    4.3 and up
# 10473             Tools     August 7, 2018           6.06.14    4.4 and up
# 5664       House & Home      July 16, 2018               NaN           NaN
# 4227             Action  November 14, 2017               NaN    2.3 and up
# 1757             Action  November 14, 2017               NaN    2.3 and up
# 1735             Action  November 14, 2017               NaN    2.3 and up
# 1891             Action  November 14, 2017               NaN    2.3 and up
# 1921             Action  November 14, 2017               NaN    2.3 and up
# 565              Dating       July 7, 2018             2.4.1    4.1 and up
# 2637             Social      July 26, 2018             7.3.1    4.1 and up
# 3014             Sports      July 25, 2018            6.17.2    4.4 and up
# 3055             Sports      July 25, 2018            6.17.2    4.4 and up
# 3063             Sports      July 25, 2018            6.17.2    4.4 and up
# 3085             Sports      July 25, 2018            6.17.2    4.4 and up
# 3118     Travel & Local     August 2, 2018               NaN           NaN
# 3202     Travel & Local     August 2, 2018               NaN           NaN
# 8291            Weather     August 6, 2018               NaN           NaN
#
#       Last_updated_parsed Size_num Installs_num Android_Ver_Clean  \
# 1407           2017-02-17  3.8e+06       500000             2.3.3
# 2543           2018-07-27  2.6e+07      1000000               5.0
# 2385           2017-01-27  3.8e+06         1000             4.0.3
# 1434           2018-08-02  1.5e+07       100000               4.1
# 5415           2018-07-29  2.5e+07     10000000               4.1
# 7035           2018-06-06  1.1e+07          100               4.1
# 3953           2018-07-31  5.2e+07    100000000             4.0.3
# 1703           2018-07-31  5.2e+07    100000000             4.0.3
# 1755           2018-07-31  5.2e+07    100000000             4.0.3
# 1844           2018-07-31  5.2e+07    100000000             4.0.3
# 1970           2018-07-31  5.2e+07    100000000             4.0.3
# 1871           2018-07-31  5.2e+07    100000000             4.0.3
# 1324           2018-07-11  6.7e+07     10000000               5.0
# 662            2018-08-01  1.5e+07      1000000               4.2
# 2402           2017-10-02  6.8e+07         1000               4.0
# 946            2018-07-16  1.9e+07      1000000               4.4
# 977            2018-07-16  1.9e+07      1000000               4.4
# 4991           2018-07-16  1.9e+07      1000000               4.4
# 10768          2018-06-22  2.4e+07        10000               5.0
# 3806           2018-06-06  3.5e+07      1000000               5.0
# 4928           2018-05-24  1.4e+07      1000000               4.1
# 5448           2017-05-25  4.6e+06      1000000               4.0
# 2378           2016-10-03  2.5e+07        10000               2.2
# 2800           2018-07-30  2.2e+07     10000000               4.4
# 280            2018-08-02  8.5e+06       100000               4.1
# 5512           2018-08-02      NaN     50000000               NaN
# 1143           2018-07-31      NaN      1000000               NaN
# 279            2018-07-31  1.1e+07      1000000               4.0
# 2488           2018-07-16  1.4e+07      1000000               4.4
# 3895           2018-04-17      NaN    100000000               NaN
# ...                   ...      ...          ...               ...
# 695            2018-08-02  7.7e+07      5000000               4.1
# 4123           2018-06-07  1.1e+07    100000000               4.0
# 4222           2018-06-08  1.1e+07    500000000               4.0
# 383            2018-06-08  1.1e+07    500000000               4.0
# 465            2018-06-08  1.1e+07    500000000               4.0
# 261            2018-07-16      NaN      1000000               4.4
# 282            2018-07-16      NaN      1000000               4.4
# 4322           2018-08-02    2e+07     50000000               4.1
# 558            2018-07-24  2.5e+07       100000             4.0.3
# 673            2018-07-24  2.5e+07       100000             4.0.3
# 4593           2018-07-18      NaN     50000000               5.0
# 6194           2018-07-23  3.5e+07      1000000               5.0
# 2367           2018-08-06  3.6e+07      1000000               5.0
# 2618           2017-10-16  3.4e+07     50000000               4.3
# 10473          2018-08-07  4.1e+06     10000000               4.4
# 5664           2018-07-16      NaN      1000000               NaN
# 4227           2017-11-14      NaN    100000000               2.3
# 1757           2017-11-14      NaN    100000000               2.3
# 1735           2017-11-14      NaN    100000000               2.3
# 1891           2017-11-14      NaN    100000000               2.3
# 1921           2017-11-14      NaN    100000000               2.3
# 565            2018-07-07  6.1e+06      1000000               4.1
# 2637           2018-07-26  2.8e+07     10000000               4.1
# 3014           2018-07-25  3.4e+07     10000000               4.4
# 3055           2018-07-25  3.4e+07     10000000               4.4
# 3063           2018-07-25  3.4e+07     10000000               4.4
# 3085           2018-07-25  3.4e+07     10000000               4.4
# 3118           2018-08-02      NaN     50000000               NaN
# 3202           2018-08-02      NaN     50000000               NaN
# 8291           2018-08-06  3.8e+07     10000000               NaN
#
#       Current_Ver_Clean
# 1407                1.9
# 2543              7.4.1
# 2385              1.0.5
# 1434              3.0.0
# 5415              5.5.9
# 7035              1.0.1
# 3953              4.0.0
# 1703              4.0.0
# 1755              4.0.0
# 1844              4.0.0
# 1970              4.0.0
# 1871              4.0.0
# 1324              3.5.0
# 662               8.7.2
# 2402             2.1.35
# 946               3.1.4
# 977               3.1.4
# 4991              3.1.4
# 10768             2.3.1
# 3806            3.19.11
# 4928             3.1.12
# 5448              4.4.3
# 2378              2.1.1
# 2800              4.4.9
# 280              5.20.7
# 5512                NaN
# 1143                NaN
# 279             2.6.158
# 2488             2.25.0
# 3895                NaN
# ...                 ...
# 695               5.0.8
# 4123   9.8.000000010492
# 4222   9.8.000000010501
# 383    9.8.000000010501
# 465    9.8.000000010501
# 261           4.3.0.508
# 282           4.3.0.508
# 4322              2.4.8
# 558              3.8.75
# 673              3.8.75
# 4593                NaN
# 6194             3.52.0
# 2367             3.52.1
# 2618              4.2.1
# 10473           6.06.14
# 5664                NaN
# 4227                NaN
# 1757                NaN
# 1735                NaN
# 1891                NaN
# 1921                NaN
# 565               2.4.1
# 2637              7.3.1
# 3014             6.17.2
# 3055             6.17.2
# 3063             6.17.2
# 3085             6.17.2
# 3118                NaN
# 3202                NaN
# 8291                NaN
#
# [1181 rows x 18 columns]

# %%
playstore = playstore.drop(duplicati_cut.index)

# %% [markdown]
# # For each category, compute the number of apps

# %%
#Per effettuare queste analisi correttamente risulta necessario eliminare il record numero 10472 in quanto traslato
playstore = playstore.drop(10472)
playstore.groupby('Category').size()
# Out:
# Category
# ART_AND_DESIGN           64
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     222
# BUSINESS                420
# COMICS                   56
# COMMUNICATION           315
# DATING                  171
# EDUCATION               119
# ENTERTAINMENT           102
# EVENTS                   64
# FAMILY                 1832
# FINANCE                 345
# FOOD_AND_DRINK          112
# GAME                    959
# HEALTH_AND_FITNESS      288
# HOUSE_AND_HOME           74
# LIBRARIES_AND_DEMO       84
# LIFESTYLE               369
# MAPS_AND_NAVIGATION     131
# MEDICAL                 395
# NEWS_AND_MAGAZINES      254
# PARENTING                60
# PERSONALIZATION         376
# PHOTOGRAPHY             281
# PRODUCTIVITY            374
# SHOPPING                202
# SOCIAL                  239
# SPORTS                  325
# TOOLS                   827
# TRAVEL_AND_LOCAL        219
# VIDEO_PLAYERS           163
# WEATHER                  79
# dtype: int64

# %% [markdown]
# # For each category, compute the average rating

# %%
playstore.groupby('Category')['Rating'].mean()
# Out:
# Category
# ART_AND_DESIGN         4.357377
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.344970
# BUSINESS               4.098479
# COMICS                 4.181481
# COMMUNICATION          4.121484
# DATING                 3.970149
# EDUCATION              4.364407
# ENTERTAINMENT          4.135294
# EVENTS                 4.435556
# FAMILY                 4.179664
# FINANCE                4.115563
# FOOD_AND_DRINK         4.172340
# GAME                   4.247368
# HEALTH_AND_FITNESS     4.243033
# HOUSE_AND_HOME         4.150000
# LIBRARIES_AND_DEMO     4.178125
# LIFESTYLE              4.093355
# MAPS_AND_NAVIGATION    4.036441
# MEDICAL                4.166552
# NEWS_AND_MAGAZINES     4.121569
# PARENTING              4.300000
# PERSONALIZATION        4.332215
# PHOTOGRAPHY            4.157414
# PRODUCTIVITY           4.183389
# SHOPPING               4.230000
# SOCIAL                 4.247291
# SPORTS                 4.216154
# TOOLS                  4.039554
# TRAVEL_AND_LOCAL       4.069519
# VIDEO_PLAYERS          4.044595
# WEATHER                4.243056
# Name: Rating, dtype: float64

# %% [markdown]
# # Create two dataframes: one for the genres and one bridging apps and genders. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
lista_app = []
lista_genres = []

for index,row in playstore.iterrows():
    app = row['Genres'].split(';')
    for genre in app:
        lista_genres.append(genre)
        lista_app.append(row['App'])


app_genre = pd.DataFrame({'App' : lista_app, 'Genres_one' : lista_genres})
app_genre.head()
# Out:
#                                                  App    Genres_one
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2                                Coloring book moana  Pretend Play
# 3  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 4                              Sketch - Draw & Paint  Art & Design

# %%
df_genres = pd.DataFrame({'Genres' : list(set(lista_genres))})
df_genres.head()
# Out:
#               Genres
# 0             Social
# 1      Entertainment
# 2            Finance
# 3             Racing
# 4  Books & Reference

# %% [markdown]
# # For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
# %%time
l_false = [False] * playstore.shape[0] #Lista di False
lista_generi = list(set(lista_genres)) #Lista con generi univoci

for genere in lista_generi:
    playstore[genere] = l_false #Inserisco in Playstore un attributo per ogni genere i cui valori sono tutti False
    
for index,row in playstore.iterrows():
    appoggio = row['Genres'].split(';')
    for genre in appoggio:
        genre.strip()
        playstore.at[index, genre] = True #Setto a True tutti i valori degli attributi riguardanti il genere/generi dell'app

playstore
# Out:
# Wall time: 822 ms

# %% [markdown]
# # For each genre, compute the average rating. What is the genre with highest average?

# %%
dff = pd.merge(app_genre, playstore, on='App')
dff.groupby('Genres_one')['Rating'].mean()
# Out:
# Genres_one
# Action                     4.247697
# Action & Adventure         4.288542
# Adventure                  4.191026
# Arcade                     4.277838
# Art & Design               4.350000
# Auto & Vehicles            4.190411
# Beauty                     4.278571
# Board                      4.287719
# Books & Reference          4.343275
# Brain Games                4.357143
# Business                   4.098479
# Card                       4.082609
# Casino                     4.286486
# Casual                     4.141014
# Comics                     4.181481
# Communication              4.121790
# Creativity                 4.306250
# Dating                     3.970149
# Education                  4.290630
# Educational                4.100000
# Entertainment              4.093028
# Events                     4.435556
# Finance                    4.115563
# Food & Drink               4.172340
# Health & Fitness           4.243496
# House & Home               4.150000
# Libraries & Demo           4.178125
# Lifestyle                  4.094040
# Maps & Navigation          4.036441
# Medical                    4.166552
# Music                      4.219048
# Music & Audio              4.300000
# Music & Video              4.229032
# News & Magazines           4.121569
# Parenting                  4.300000
# Personalization            4.332215
# Photography                4.157414
# Pretend Play               4.238235
# Productivity               4.183389
# Puzzle                     4.370732
# Racing                     4.174757
# Role Playing               4.272072
# Shopping                   4.230000
# Simulation                 4.154500
# Social                     4.247291
# Sports                     4.225185
# Strategy                   4.227368
# Tools                      4.039554
# Travel & Local             4.069519
# Trivia                     4.039286
# Video Players & Editors    4.044667
# Weather                    4.243056
# Word                       4.340909
# Name: Rating, dtype: float64

# %%
#Rating medio massimo
dff.groupby('Genres_one')['Rating'].mean().idxmax()
# Out:
# 'Events'

# %% [markdown]
# # For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
#ispezione price
print(playstore.Price.isnull().any())#no missing
playstore.groupby('Price').size()
#quindi il valore o è 0 o ha come valuta il $
# Out:
# False
# Price
# $0.99       145
# $1.00         3
# $1.04         1
# $1.20         1
# $1.26         1
# $1.29         1
# $1.49        46
# $1.50         1
# $1.59         1
# $1.61         1
# $1.70         2
# $1.75         1
# $1.76         1
# $1.96         1
# $1.97         1
# $1.99        73
# $10.00        2
# $10.99        2
# $109.99       1
# $11.99        3
# $12.99        4
# $13.99        2
# $14.00        1
# $14.99        9
# $15.46        1
# $15.99        1
# $154.99       1
# $16.99        2
# $17.99        2
# $18.99        1
#            ...
# $389.99       1
# $39.99        2
# $394.99       1
# $399.99      12
# $4.29         1
# $4.49         9
# $4.59         1
# $4.60         1
# $4.77         1
# $4.80         1
# $4.84         1
# $4.85         1
# $4.99        70
# $400.00       1
# $46.99        1
# $5.00         1
# $5.49         5
# $5.99        26
# $6.49         5
# $6.99        11
# $7.49         2
# $7.99         7
# $74.99        1
# $79.99        1
# $8.49         2
# $8.99         5
# $89.99        1
# $9.00         1
# $9.99        19
# 0          8903
# Length: 92, dtype: int64

# %%
playstore['Price_number'] = playstore['Price'].apply(lambda x: float(x.strip('$'))) #Rimuovo eventuale valuta
playstore[playstore['Price'] != '0'][['Price','Price_number']].head()#verifica se prezzo è trasformato correttamento (0 escluso)
# Out:
#      Price  Price_number
# 234  $4.99          4.99
# 235  $4.99          4.99
# 427  $3.99          3.99
# 476  $3.99          3.99
# 477  $6.99          6.99

# %%
playstore['Income'] = playstore['Price_number'] * playstore['Installs_num']
playstore[playstore['Price'] != '0'][['Price','Installs','Income']].head()
# Out:
#      Price  Installs  Income
# 234  $4.99  100,000+  499000
# 235  $4.99  100,000+  499000
# 427  $3.99  100,000+  399000
# 476  $3.99   10,000+   39900
# 477  $6.99    1,000+    6990

# %% [markdown]
# # For each app, compute its minimum and maximum Sentiment_polarity

# %%
sent_max = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].max()).reset_index()
sent_min = pd.DataFrame(playstore_review.groupby('App')['Sentiment_Polarity'].min()).reset_index()
sent = pd.merge(sent_max,sent_min, on='App')
sent.rename(columns={'Sentiment_Polarity_x':'Sentiment_Polarity_max','Sentiment_Polarity_y':'Sentiment_Polarity_min'}).head()
# Out:
#                                 App  Sentiment_Polarity_max  \
# 0             10 Best Foods for You                1.000000
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.910000
# 2                              11st                1.000000
# 3        1800 Contacts - Lens Store                0.838542
# 4   1LINE – One Line with One Touch                1.000000
#
#    Sentiment_Polarity_min
# 0                 -0.8000
# 1                 -0.1125
# 2                 -1.0000
# 3                 -0.3000
# 4                 -0.8250
